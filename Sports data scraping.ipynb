# %%
import requests

# %%
url = 'https://www.skysports.com/premier-league-table/2011'

# %%
page = requests.get(url)

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# <!doctype html>
# <html lang="en" class="no-js">
# <head>
#
#     <meta charset="utf-8">
#     <title>Premier League Table & Standings - Sky Sports Football</title>
#     <meta name="robots" content="NOODP,INDEX,FOLLOW" />
#     <meta name="description" content="Complete table of Premier League standings for the 2011/2012 Season, plus access to tables from past seasons and other Football leagues."/>
#     <meta name="keywords" content="Sky, Sports, Football, News, Premier, League, Fixtures, Results, Tables, Photos, Transfer, Centre, Arsenal, Aston Villa, Birmingham City, Blackburn Rovers, Bolton Wanderers, Burnley, Chelsea, Everton, Fulham, Hull City, Liverpool, Manchester City, Man City, Manchester United, Man Utd, Portsmouth, Stoke City, Sunderland, Tottenham Hotspur, Spurs, West Ham, Wigan Athletic, Wolverhampton Wanderers, Wolves, watch, video, live, pc. torress, benitez"/>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"517f0b291f",applicationID:"545304393"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(8),f=t(9),c=t("ee").get("tracer"),u=t("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(t,e){s[e]=i(p+e,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),t,n],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],n),t}finally{c.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(l+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){function r(){return f.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,f=t(10);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],4:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],5:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof m&&!g){var e=Math.round(t.timeStamp),n={type:t.type};e<=p.now()?n.fid=p.now()-e:e>p.offset&&e<=Date.now()?(e-=p.offset,n.fid=p.now()-e):e=p.now(),g=!0,d("timing",["fi",e,n])}}function f(t){d("pageHide",[p.now(),t])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var c,u,s,d=t("handle"),p=t("loader"),l=t(7),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){c=new PerformanceObserver(r);try{c.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,h=["click","keydown","mousedown","pointerdown","touchstart"];h.forEach(function(t){document.addEventListener(t,a,!1)})}l(f)}},{}],6:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}e.exports={agent:i,version:o,match:r}},{}],7:[function(t,e,n){function r(t){function e(){t(a&&document[a] ...
#
#         <link rel="dns-prefetch" href="//e0.365dm.com">
#         <link rel="dns-prefetch" href="//e1.365dm.com">
#         <link rel="dns-prefetch" href="//e2.365dm.com">
#         <link rel="dns-prefetch" href="//fresh8.co">
#         <link rel="dns-prefetch" href="//annex.fresh8.co">
#         <link rel="dns-prefetch" href="//cdn-gs.fresh8.co">
#         <link rel="dns-prefetch" href="//player.ooyala.com">
#         <link rel="dns-prefetch" href="//static.chartbeat.com">
#         <link rel="dns-prefetch" href="//assets.adobedtm.com">
#         <link rel="dns-prefetch" href="//img.skysports.com">
#         <link rel="dns-prefetch" href="//video.skysports.com">
#         <link rel="dns-prefetch" href="//cdn.livefyre.com">
#         <link rel="dns-prefetch" href="//app-cdn.spot.im">
#         <link rel="dns-prefetch" href="//cdn.teads.tv">
#         <link rel="dns-prefetch" href="//services.babator.com">
#         <link rel="dns-prefetch" href="//eu-services.babator.com">
#         <link rel="dns-prefetch" href="//widgets.oddschecker.com">
#         <link rel="dns-prefetch" href="//pagead2.googlesyndication.com">
#         <link rel="dns-prefetch" href="//metrics-api.librato.com">
#         <link rel="dns-prefetch" href="//cloud-static.storage.googleapis.com">
#         <link rel="dns-prefetch" href="//analytics.ooyala.com">
#         <link rel="dns-prefetch" href="//l.ooyala.com">
#
#     <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-title" content="Sky Sports">
#     <meta name="application-name" content="SkySports">
#     <meta name="viewport" id="viewport" content="width=device-width,maximum-scale=1,minimum-scale=1,minimal-ui">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="google-site-verification" content="GeOj3ib0hXB5Iewz4HWUfve0FidZUHpPXlBi6oPOTjU" />
#     <meta property="fb:pages" content="10911153761" /><meta property="fb:admins" content="509247152,100000206570823" />
# <meta property="og:title" content="Premier League (Sky Sports)" />
# <meta property="og:url" content="https://www.skysports.com/premier-league-table/2011" />
# <meta property="og:description" content="Get the latest Premier League Football news, fixtures, results, video and more from Sky Sports." />
# <meta property="og:site_name" content="SkySports" />
#
# <script>
# if ((/iPad|iPhone|iPod/).test(navigator.userAgent)) {
#     var headNode = document.getElementsByTagName('head')[0];
#     var sbNode = document.createElement('meta');
#     sbNode.name = 'apple-itunes-app';
#     sbNode.content = 'app-id=500102120';
#     headNode.appendChild(sbNode);
# }
# </script>
#
#
#     <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />
# <link rel="apple-touch-icon-precomposed" href="/apple-touch-icon-precomposed.png" />
#
#         <style data-webfont-src="/static/skytext-reg-bce1c746d381a.css"></style>
#     <style data-webfont-src="/static/skytext-med-c849e3d033da4.css"></style>
#     <style data-webfont-src="/static/skycons-baae5a5793309.css"></style>
#
#             <link rel="stylesheet" href="/static/skysports-digrev-b2b2f1ef15554.css" type="text/css" media="all" title="default" />
#
#     <!--[if IE 8]>
#         <link rel="stylesheet" type="text/css" href="/static/skysports-digrev-ie8-b40bc63c79e5f.css">
#     <![endif]-->
#
#     <script id="script-polyfills" data-grade-b-src="/static/head-grade-b-6a22e81a4779c.js" data-grade-c-src="/static/head-grade-c-a4c5458d881fc.js"></script>
#     <script>// google ads set up
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         googletag.adSlots = {};</script>
#           <script type="text/javascript">
#       var _sf_async_config = _sf_async_config || {};
#       _sf_async_config.uid = '43610';
#       _sf_async_config.domain = 'skysports.com';
#       _sf_async_config.flickerControl = false;
#       _sf_async_config.useCanonical = true;
#   </script>
#
#
#     <script>window.SKY_SPORTS = window.SKY_SPORTS || {
#     deferedFunctionsCalled: !1,
#     deferredArray: [],
#     deferred: function(e) {
#         this.deferredArray.push(e);
#     },
#     callDeferredFunctions: function() {
#         if (!this.deferedFunctionsCalled) {
#             for (var e = -1; ++e < this.deferredArray.length; ) this.deferredArray[e] && this.deferredArray[e].call();
#             this.deferedFunctionsCalled = !0;
#         }
#     },
#     initIframeWidget: function(t) {
#         window.addEventListener("message", function(e) {
#             t.style.height = e.data + "px";
#         });
#     }
# }, function() {
#     window.aab = window.aab || {}, aab.playerLoaded = function(y) {
#         y = y || "OO", aab.playerLoadedCalled = y, window[y].aabPluginLoaded || window[y].plugin("AAB", function(S, e, t, n) {
#             aab.addingPlugin = !0, aab.OO = S;
#             return function(t, e) {
#                 var i, a, n, o, r, s, d = !(window[y].aabPluginLoaded = !0), c = !1, l = 3e4, u = 1e3;
#                 function m() {
#                     var e = new Date().getTime();
#                     o = o || e, d || (null == n || S.supportsFlash) && (c && !r || (!s && n.error && f(0, n.error),
#                     l < e - o ? p() : setTimeout(m, u)));
#                 }
#                 function p() {
#                     function e() {
#                         var e = document.createElement("div");
#                         e.style.height = "100%", e.style.backgroundColor = "#000", e.style.color = "#999",
#                         e.style.textAlign = "center", e.innerHTML = "<br><br>An error occurred when loading the player.<br>Please review your connection settings and try again.",
#                         document.getElementById(i).innerHTML = "", document.getElementById(i).appendChild(e);
#                     }
#                     n.destroy(), t.subscribe(S.EVENTS.DESTROY, "aab", e), e();
#                 }
#                 function f(e, t) {
#                     s = t && "cannotDownloadThirdPartyModule" === t.code && "flash" === t.source;
#                 }
#                 function h() {
#                     d = !0;
#                     var a = console.error;
#                     console.error = function() {
#                         a.apply || Function.prototype.apply.apply(a, [ console, arguments ]), a.apply(console, arguments);
#                         var e = arguments && 0 < arguments.length ? arguments[0] : "";
#                         if (e.match(/Error\: Ad adLoadError/i)) {
#                             var t = document.getElementById(i).getElementsByTagName("object"), n = null;
#                             t && (1 == t.length ? n = t[0] : 2 == t.length && (n = t[1])), n && (e.match(/errorCode\: 1001/i) ? n.adLoadEmptyVast && n.adLoadEmptyVast() : n.adLoadError && n.adLoadError());
#                         }
#                     };
#                 }
#                 function w() {
#                     !n && S.supportsFlash && (n = S.players[i]) && (t.subscribe("aabLoaded", "aab", h),
#                     t.subscribe("aabBlocked", "aab", p), t.subscribe("preDetectionComplete", "aab", function() {}),
#                     t.subscribe("noAdBlockerDetected", "aab", function() {}), t.subscribe("adBlockerDetected", "aab", function() {}),
#                     setTimeout(m, u));
#                 }
#                 S.supportsFlash && (t.subscribe(S.EVENTS.PLAYER_CREATED, "aab", function(e, t, n) {
#                     i = t, a = n;
#                 }), t.subscribe(S.EVENTS.PLAYER_EMBEDDED, "aab", w), t.subscribe(S.EVENTS.METADATA_FETCHED, "aab", function(e, t) {
#                     for (var n in w(), c = !0, r = !!t.base.aabEnabled && "true" === t.base.aabEnabled,
#                     function() {
#                         if (!r) {
#                             var e = "anti-adblocker";
#                             a.devModuleURL && a.devModuleURL.toLowerCase().indexOf("aabadsmanager.swf") && (e = "dev-other"),
#                             a[e] && a[e].aab && a[e].aab.aabEnabled && (r = !0);
#                         }
#                     }(), t.modules) ;
#                 }), t.subscribe(S.EVENTS.ERROR, "aab", f));
#             };
#         });
#     };
#     var n = [ "OO", "OoyalaPlayer1", "OoyalaPlayer2", "OoyalaPlayer3", "OoyalaPlayer4", "OoyalaPlayer5", "OoyalaPlayer6", "OoyalaPlayer7", "OoyalaPlayer8" ];
#     function e() {
#         aab.onReadyCalled = !0;
#         for (var e = 0; e < n.length; e++) {
#             var t = n[e];
#             if (window[t]) {
#                 aab.namespaceFound = t, aab.playerLoaded(t);
#                 break;
#             }
#         }
#     }
#     document.addEventListener ? (aab.eventListenerType = "addEventListener", document.addEventListener("DOMContentLoaded", e)) : document.attachEvent && (aab.eventListenerType = "attachEvent",
#     aab.onreadystatechangeFired = !1, document.attachEvent("onreadystatechange", function() {
#         aab.onreadystatechangeFired = !0, "complete" === document.readyState && (document.detachEvent("onreadystatechange", arguments.callee),
#         e());
#     })), e();
# }(), function() {
#     for (var i = 0, e = [ "moz", "webkit" ], t = 0; t < e.length && !window.requestAnimationFrame; ++t) window.requestAnimationFrame = window[e[t] + "RequestAnimationFrame"],
#     window.cancelAnimationFrame = window[e[t] + "CancelAnimationFrame"] || window[e[t] + "CancelRequestAnimationFrame"];
#     window.requestAnimationFrame || (window.requestAnimationFrame = function(e) {
#         var t = new Date().getTime(), n = Math.max(0, 16 - (t - i)), a = window.setTimeout(function() {
#             e(t + n);
#         }, n);
#         return i = t + n, a;
#     }), window.cancelAnimationFrame || (window.cancelAnimationFrame = function(e) {
#         clearTimeout(e);
#     });
# }(), function() {
#     var e = document.createElement("div");
#     e.setAttribute("data-a", "b"), e.className = "a";
#     var t = document.getElementById("script-polyfills");
#     t && ("addEventListener" in window && Function.prototype.bind && String.prototype.trim && "textContent" in e && Array.prototype.indexOf || document.write("<script src='" + t.getAttribute("data-grade-c-src") + "'><\/script>"),
#     "classList" in e && "dataset" in e || document.write("<script src='" + t.getAttribute("data-grade-b-src") + "'><\/script>"));
# }(), SKY_SPORTS.getUa = function(t) {
#     function e(e) {
#         return !!t.match(e) && parseFloat(t.match(e)[1].replace("_", "."));
#     }
#     var n = !1;
#     null !== new RegExp("MSIE ([0-9]{1,}[.0-9]{0,})").exec(t) && (n = parseFloat(RegExp.$1));
#     var a = t.match(/iPad/), i = t.match(/iP/), o = t.match(/android/i), r = t.match(/windows phone/i), s = navigator.platform.match(/mac|win/i), d = {
#         classList: ""
#     };
#     return r && ((d = {
#         mobile: !0,
#         windowsphone: !0,
#         name: "windowsphone",
#         version: e(/os ([0-9]\.[0-9])/i) || e(/windows phone ([0-9]\.[0-9])/i)
#     }).classList = [ d.name, d.name + d.version, "mobile" ].join(" ")), n && ((d = {
#         msie: !0,
#         name: "msie",
#         version: n
#     }).classList = [ d.name, d.name + d.version ].join(" ")), (a || i) && ((d = {
#         ios: !0,
#         name: a ? "ipad" : "iphone",
#         mobile: !0,
#         version: e(/os ([1-9]\_[0-9])/i)
#     }).classList = [ d.name, d.name + d.version, d.device, "ios", "ios" + d.version, "mobile" ].join(" ")),
#     o && ((d = {
#         android: !0,
#         name: "android",
#         mobile: !0,
#         version: e(/android ([1-9]\.[0-9])/i)
#     }).classList = [ d.name, d.name + d.version, "mobile" ].join(" ")), s && (d.desktop = !0,
#     d.classList += " desktop"), d;
# }, SKY_SPORTS.getFeatures = function(n, e) {
#     function t(e, t) {
#         return n.classList += t ? " " + e : " no-" + e, t;
#     }
#     e.style.cssText = "-webkit-animation-name:shim;animation-name:shim;-moz-animation-name:shim;width:10vw",
#     n.hasTouch = t("touch", "ontouchstart" in window || "DocumentTouch" in window && document instanceof window.DocumentTouch),
#     n.hasSvg = t("svg", !!document.implementation.hasFeature("http://www.w3.org/TR/SVG11/feature#BasicStructure", "1.1")),
#     n.hasCssAnimations = t("cssanimations", !!(e.style.animationName || e.style.webkitAnimationName || e.style.mozAnimationName)),
#     n.hasVpUnits = t("vpunits", !!e.style.width), n.hasWebWorkers = t("web-workers", !!window.Worker);
#     var a = {
#         webkitAnimation: "webkitAnimationStart",
#         mozAnimation: "mozAnimationStart",
#         animation: "animationstart",
#         msAnimation: "MSAnimationStart"
#     };
#     for (var i in a) i in e.style && (n.animationEventName = a[i]);
#     return n;
# }, SKY_SPORTS.device = SKY_SPORTS.getUa(navigator.userAgent), SKY_SPORTS.getFeatures(SKY_SPORTS.device, document.createElement("div")),
# document.documentElement.className = "js " + SKY_SPORTS.device.classList, function(t, e) {
#     t.SKY_SPORTS = t.SKY_SPORTS || {}, localStorage.removeItem("jscss");
#     var n = e.createElement("style"), a = "ss.js.styles", i = {}, o = t.localStorage.getItem(a);
#     function r() {
#         var e = function() {
#             var e = "";
#             for (var t in i) e += i[t];
#             return e;
#         }();
#         n.styleSheet ? n.styleSheet.cssText = e : n.textContent = e, t.localStorage.setItem(a, JSON.stringify(i));
#     }
#     n.id = a, e.getElementsByTagName("head")[0].appendChild(n), o && (i = JSON.parse(o)),
#     r(), t.SKY_SPORTS.addCss = function(e) {
#         e.id in i != 0 && i[e.id] === e.css || (i[e.id] = e.css), r();
#     }, t.SKY_SPORTS.removeCss = function(e) {
#         e in i && delete i[e], r();
#     };
# }(window, document), function(r) {
#     function s(e, t) {
#         t.match("font-family: 'SkyTextMed'") && (t += t.replace("font-family: 'SkyTextMed'", "font-weight: 600; font-family: 'skytext'")),
#         t.match("font-family: 'SkyTextReg'") && (t += t.replace("font-family: 'SkyTextReg'", "font-weight: 400; font-family: 'skytext'")),
#         e.styleSheet ? e.styleSheet.cssText = t : e.textContent = t;
#     }
#     SKY_SPORTS.getFont = function(t, e) {
#         if ("keys" in Object != !1) {
#             var n, a;
#             n = e.split("/").pop(), (a = n.split("-")).splice(-1), a = a.join("-");
#             var i = r.localStorage.getItem(n);
#             if (i) s(t, i); else {
#                 Object.keys(r.localStorage).forEach(function(e) {
#                     e.match(a) && r.localStorage.removeItem(e);
#                 });
#                 var o = new XMLHttpRequest();
#                 o.onreadystatechange = function() {
#                     if (4 === this.readyState && 200 === this.status) {
#                         var e = this.responseText;
#                         s(t, e), r.localStorage.setItem(n, e);
#                     }
#                 }, o.open("GET", e, !0), o.send();
#             }
#         }
#     };
#     for (var e = document.querySelectorAll("style[data-webfont-src]"), t = -1; ++t < e.length; ) SKY_SPORTS.getFont(e[t], e[t].getAttribute("data-webfont-src"));
# }(window), function(t, n) {
#     "use strict";
#     if (n.currentBreakPoint = 10, n.currentAdvertBreakPoint = "display", n.getBreakPoint = function() {
#         var e = t.getComputedStyle(n.body, ":after").getPropertyValue("content");
#         return e = parseInt(e.replace(/['"]/g, ""), 10);
#     }, n.getAdvertBreakPoint = function() {
#         return t.getComputedStyle(n.body, ":before").getPropertyValue("content").replace(/['"]/g, "");
#     }, Function.prototype.debounce = function(e) {
#         var t = this;
#         return function() {
#             t.args = arguments, t.timeout_id && clearTimeout(t.timeout_id), t.timeout_id = setTimeout(function() {
#                 return t.apply(t, t.args);
#             }, e);
#         };
#     }, n.createEvent) {
#         var a = n.createEvent("Event");
#         a.initEvent("breakPointChange", !0, !0);
#         var i = n.createEvent("Event");
#         i.initEvent("advertChange", !0, !0), t.addEventListener("DOMContentLoaded", function() {
#             n.currentBreakPoint = n.getBreakPoint(), n.currentAdvertBreakPoint = n.getAdvertBreakPoint();
#         }, !1), t.addEventListener("resize", function() {
#             var e = n.getBreakPoint(), t = n.getAdvertBreakPoint();
#             e !== n.currentBreakPoint && (n.currentBreakPoint = e, n.dispatchEvent(a)), t !== n.currentAdvertBreakPoint && (n.currentAdvertBreakPoint = t,
#             n.dispatchEvent(i));
#         }.debounce(300), !1);
#     }
# }(window, document), function() {
#     function s(e) {
#         for (var t = document.cookie.split(";"), n = -1; ++n < t.length; ) {
#             var a = t[n].split("=");
#             if (a[0].match(e)) return decodeURIComponent(a[1]);
#         }
#         return "";
#     }
#     function d() {
#         var e = window.SKY_SPORTS.user;
#         return e.isLoggedIn ? e.isSkySports ? 1 : e.isWholesale ? 3 : 4 : 2;
#     }
#     window.SKY_SPORTS = window.SKY_SPORTS || {}, function e() {
#         var t, n, a = s("interactive"), i = a ? JSON.parse(a) : {}, o = s("skySportsSSO"), r = {
#             isLoggedIn: (t = o, !!t),
#             getType: d,
#             set: e
#         };
#         r.isLoggedIn && (r.name = i.f || "", r.isSkyHD = 1 === i.hd, r.isSky = 1 === i.st,
#         r.isSkySports = 2 === i.st, r.isNowTV = 3 === i.st, r.isWholesale = !(!(n = o) || !n.match(/^WIG/))),
#         window.SKY_SPORTS.user = r, function(e) {
#             var t = e.getType(), n = 1 === t || 3 === t ? '.item[data-role="nosub"]{display:none!important}.item[data-role="sub"]{display:inline-block!important}' : '.item[data-role="sub"] {display:none!important}';
#             n += 1 !== t || e.isWholesale ? "" : ".remote-record-link.-hdn {display:block!important}";
#             var a = e.isWholesale ? "[data-not-for-wholesale]{display:none!important}" : "";
#             window.SKY_SPORTS.addCss({
#                 id: "userTypeButton",
#                 css: '.button[data-role="subscriber-promo-button"]:after{content:attr(data-usertype' + t + ")}" + n + a
#             }), window.SKY_SPORTS.addCss({
#                 id: "userLabel",
#                 css: ".user-label:after{content:attr(data-label-type" + t + ")}"
#             });
#         }(window.SKY_SPORTS.user);
#     }();
# }(), SKY_SPORTS.postpone = {
#     funcs: {},
#     init: function() {
#         this.items = document.getElementsByClassName("postpone"), this.addFunc("removeclass", function() {
#             var e = this.getAttribute("data-postpone-removeclass");
#             e && this.classList.remove(e), this.classList.remove("postpone");
#         }), this.scan();
#     },
#     addFunc: function(e, t) {
#         this.funcs[e] = t;
#     },
#     scan: function() {
#         for (var e = -1; ++e < this.items.length; ) {
#             var t, n = this.items[e];
#             n.whenVisible || (t = n.getAttribute("data-postpone-call")) && this.funcs[t] && (n.whenVisible = this.funcs[t],
#             n.setAttribute("data-postpone-class", this.className), n.detach = this.detach),
#             this.isInViewPort(n) && n.whenVisible();
#         }
#         var a = this;
#         setTimeout(function() {
#             window.requestAnimationFrame(a.scan.bind(a));
#         }, 50);
#     },
#     isInViewPort: function(e) {
#         var t = e.getBoundingClientRect();
#         return 0 !== t.width && (!(t.bottom < 0) && !(window.innerHeight - t.top < 0));
#     }
# }, SKY_SPORTS.postpone.init();</script>
#
#         <script src="//assets.adobedtm.com/launch-ENd3e4df0dfde7473d823092cac7cd0611.min.js"></script>
#         <script type="text/javascript">
#         !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
#     </script>
#     <script>
#         window._sp_ = {
#             config: {
#                 accountId: 630,
#                 propertyId: 2370,
#                 wrapperAPIOrigin: "https://wrapper-api.sp-prod.net/tcfv2",
#                 mmsDomain: "https://message630.sp-prod.net",
#
#             }
#         }
#     </script>
#     <script src="https://gdpr-tcfv2.sp-prod.net/wrapperMessagingWithoutDetection.js"></script>
#
#     <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
#
# </head>
# <body  >
#     <div class="site-header">
#
#     <div class="site-header__body">
#
#         <div class="site-header__col site-header__col1">
#             <a href="https://www.skysports.com" class="svg-logo site-header__logo">
#                 <img class="svg-logo__image" src="/core/img/channels/Sky-Sports-Logo-transparent.svg" onerror="this.onerror=null;this.src='/core/img/channels/Sky-Sports-Logo.png'">
#             </a>
#         </div>
#
#                 <div class="site-header__col site-header__col2">
#         <div class="site-login callfn" data-fn="skyid-login" data-lite="true">
#             <script type="text/template" class="login-text" data-role="default">
#                 <!--default-->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo"><a href="https://www.skysports.com/watch/get-sky" class="site-login__link">Get Sky Sports</a></li>
#                     <li class="site-login__item"><a class="site-login__link site-login__link--user callfn" href="https://skyid.sky.com/signin/sports?successUrl=https%3A%2F%2Fwww.skysports.com%2Fpremier-league-table%2F2011" data-mobile-url="/sso/signin/mobile" data-desktop-url="/sso/signin/desktop" data-lite="true" >Log In</a></li>
#                 </ul>
#             </script>
#             <script type="text/template" class="login-text" data-role="isSkySports">
#                 <!-- sky sports user logged in -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2011" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#             </script>
#             <script type="text/template" class="login-text" data-role="isSky">
#                 <!-- sky sports user logged in -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo">
#                         <a href="/watch/get-sky" class="site-login__link">Upgrade</a>
#                     </li>
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2011" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#             </script>
#             <script type="text/template" class="login-text" data-role="isNowTv">
#                 <!-- now tv customer -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo"><a href="https://www.skysports.com/watch/get-sky" class="site-login__link">Get Sky Sports</a></li>
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2011" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#             </script>
#             <script type="text/template" class="login-text" data-role="isLoggedIn">
#                 <!-- just a sky id login -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo"><a href="https://www.skysports.com/watch/get-sky" class="site-login__link">Get Sky Sports</a></li>
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2011" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#             </script>
#             <script type="text/template" class="login-text" data-role="isWholesale">
#                 <!-- wholesale customer -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user"></span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2011" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#             </script>
#         </div>
#     </div>
#
#     <div class="site-header__col site-header__col3">
#
#         <form action="https://www.skysports.com/search" method="GET" class="site-search">
#             <input type="text" name="q" placeholder="Search Sky Sports" accesskey="q" autocomplete="off" autocorrect="off" autocapitalize="off" class="site-search__input">
#             <input type="hidden" value="the site" name="searchtype">
#             <input type="hidden" name="v" value="2">
#             <button class="site-search__button">
#                 <span class="site-search__button-label">Search</span>
#             </button>
#         </form>
#
#     </div>
#
#     <a class="site-header__col site-header__col4 site-header__nav-button-hit-area" data-role="open-left-hand-nav" href="#no-js-nav" tabindex="1">
#         <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" viewBox="0 0 2048 2048" xml:space="preserve" class="site-header__nav-button">
#             <rect y="384" width="2048" height="256"></rect>
#             <rect y="896" width="2048" height="256"></rect>
#             <rect y="1408" width="2048" height="256"></rect>
#         </svg>
#     </a>
#
#     </div>
#
#     <!-- desktop nav -->
# <div class="site-nav-desktop__wrap adaptive-content callfn" data-fn="adaptive-content" data-lite="true" aria-hidden="true">
# <script type="text/template">
# <div class="site-nav-desktop callfn" role="navigation" data-fn="site-nav-desktop" data-lite="true">
# <ul class="site-nav-desktop__body">
# <li class="site-nav-desktop__item">
# <a href="/" class="site-nav-desktop__item-link">
# Home</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="#site-nav-desktop-sports-more-nav" class="site-nav-desktop__item-link site-nav-desktop__item-link--more" aria-controls="site-nav-desktop-sports-more-nav" id="site-nav-desktop-sports-more">
# Sports</a>
# <div class="site-nav-desktop__menu" aria-labelledby="site-nav-desktop-sports-more" id="site-nav-desktop-sports-more-nav">
# <div class="site-nav-desktop__menu-body">
# <ul class="site-nav-desktop__menu-links">
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/football">
# Football</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/f1">
# F1</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/cricket">
# Cricket</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/rugby-union">
# Rugby Union</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/rugby-league">
# Rugby League</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/golf">
# Golf</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/boxing">
# Boxing</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/nfl">
# NFL</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/olympics">
# Olympics</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/tennis">
# Tennis</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/racing">
# Racing</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/darts">
# Darts</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/nba">
# NBA</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/netball">
# Netball</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/gaa">
# GAA</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/mma">
# MMA</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/more-sports">
# More Sports</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/live-scores" class="site-nav-desktop__item-link">
# Scores</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/watch/video" class="site-nav-desktop__item-link">
# Video</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/watch" class="site-nav-desktop__item-link">
# TV</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="https://www.skybet.com?aff=9749&dcmp=ss_main_nav" class="site-nav-desktop__item-link" target="_blank">
# Sky Bet</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/games" class="site-nav-desktop__item-link">
# Games</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="#site-nav-desktop-more-more-nav" class="site-nav-desktop__item-link site-nav-desktop__item-link--more" aria-controls="site-nav-desktop-more-more-nav" id="site-nav-desktop-more-more">
# More</a>
# <div class="site-nav-desktop__menu site-nav-desktop__menu--right" aria-labelledby="site-nav-desktop-more-more" id="site-nav-desktop-more-more-nav">
# <div class="site-nav-desktop__menu-body">
# <ul class="site-nav-desktop__menu-links">
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/transfer-centre">
# Transfer Centre</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/watch/sport-on-sky">
# Live on Sky</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/get-sky?dcmp=gss_more_dropdown">
# Get Sky Sports</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/watch/tv-shows">
# TV Shows</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/watch/tv-guide">
# TV Guide</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.sky.com/shop/tv/sky-go/?dcmp=skygo_ss.com_more" target="_blank">
# Sky Go</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="http://www.nowtv.com/promo/sky-sports?dcmp=ilc_SSNTV_skysports_hardcode_moredropdownlink" target="_blank">
# Now TV</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.kickitout.org/forms/online-reporting-form" target="_blank">
# Kick It Out</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/football/news/topic/8724/black-lives-matter">
# Black Lives Matter</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/podcasts">
# Podcasts</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/mobile">
# Mobile</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://twitter.com/SkySports" target="_blank">
# Twitter</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.facebook.com/SkySports" target="_blank">
# Facebook</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/contact-us">
# Contact Us</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/workatskysports">
# Work @ Sky Sports</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.sky.com/help/articles/skycom-terms-and-conditions" target="_blank">
# Terms &amp; Conditions</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# <a href="https://www.skysports.com/watch" class="site-nav-desktop__watch-button no-default-hover no-default-active"><span class="site-nav-desktop__watch-button__label">Watch Sky Sports</span></a>
# </div>
# </script>
# </div>
# </div><div id="mobile-bet-basket"></div>    <div class="advert--banner-wrap-ghost">
#         <div class="advert--banner-wrap">
#                     <div class="block advert advert--banner">
#             <div class="advert__container" id="leaderboard">
#             </div>
#         </div>
#         </div>
#     </div>
#
# <div class="site-wrapper ">
#     <div class="grid site-layout-primary callfn" data-fn="site-layout-primary" data-lite="true">
#         <div class="grid__col site-layout-primary__col1 "  >
#     <!-- page title -->
# <div class="page-header ">
#     <ul class="page-header__breadcrumb">
#                 <li class="page-header__breadcrumb-item">
#             <h2 class="page-header__breadcrumb-title">
#                 <a class="page-header__breadcrumb-link" href="https://www.skysports.com/football">Football</a>
#             </h2>
#         </li>
#                     </ul>
#
#
#     <h1 class="page-header__title">
#         <a href="/premier-league" class="page-header__title-link">
#             <abbr class="swap-text--bp30" title="Premier League">
#                 <span class="swap-text__target">Premier League</span>
#             </abbr>
#         </a>
#                                     <span class="page-header__title-subitem">Table</span>
#                         </h1>
#
#             <div class="block page-header__sponsor">
#             <div class="advert__container" id="sponsor-position">
#             </div>
#         </div>
# </div>
# <div class="page-nav callfn" data-fn="page-nav" data-lite="true">
#             <a class="page-nav__head" href="#page-nav" aria-controls="page-nav-control" id="page-nav-control" >
#             <h3 class="page-nav__title">Table</h3>
#             <div class="page-nav__title-more"></div>
#         </a>
#         <div class="page-nav__frame">
#             <div class="page-nav__body" id="page-nav" aria-labelledby="page-nav" style=" visibility: hidden;">
#                 <ul class="page-nav__item-group">
#                                                                                                                                                                                                                                                     <li class="page-nav__item">
#                                         <a href="/premier-league-news" class="page-nav__link" >News</a>
#                                     </li>
#                                                                                                                                                 <li class="page-nav__item page-nav__item--select">
#     <select class="page-nav__select callfn"
#             tabindex="-1"
#             data-fn="implicit-personalisation-display"
#             data-lite="true"
#             data-key="football.team"
#             data-name="skysports-implicit-personalisation"
#             data-label="Your most viewed"
#             onchange="location.href=this.options[selectedIndex].value">
#         <option disabled selected="selected">Select a team</option>
#                                                 <option
#                          id="all-teams"                         class="page-nav__select-option"
#                         value="/football/teams">All Teams</option>
#                                                                 <optgroup label="Premier League">
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="413"
#                                 value="/arsenal">Arsenal</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="238"
#                                 value="/aston-villa">Aston Villa</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="194"
#                                 value="/brentford">Brentford</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="212"
#                                 value="/brighton-and-hove-albion">Brighton</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="160"
#                                 value="/burnley">Burnley</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="524"
#                                 value="/chelsea">Chelsea</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="234"
#                                 value="/crystal-palace">Crystal Palace</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="229"
#                                 value="/everton">Everton</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="183"
#                                 value="/leeds-united">Leeds United</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="152"
#                                 value="/leicester-city">Leicester City</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="155"
#                                 value="/liverpool">Liverpool</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="345"
#                                 value="/manchester-city">Manchester City</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="210"
#                                 value="/manchester-united">Manchester United</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="409"
#                                 value="/newcastle-united">Newcastle United</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="290"
#                                 value="/norwich-city">Norwich City</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="392"
#                                 value="/southampton">Southampton</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="608"
#                                 value="/tottenham-hotspur">Tottenham Hotspur</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="508"
#                                 value="/watford">Watford</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="367"
#                                 value="/west-ham-united">West Ham United</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="206"
#                                 value="/wolverhampton-wanderers">Wolverhampton</option>
#                                             </optgroup>
#                                                                 <optgroup label="Championship">
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="191"
#                                 value="/barnsley">Barnsley</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="247"
#                                 value="/birmingham-city">Birmingham City</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="262"
#                                 value="/blackburn-rovers">Blackburn Rovers</option>
#                                                     <option
#                                 class="page-nav__select-option"
#                                 data-itemid="231"
#                                 value="/blackpool">Blackpool</option>
#                                                     <option
#                                 class="page-nav__select-option"
# ...
#                       <li class="site-footer__item">
#               <a href="http://www.planetf1.com" class="site-footer__link" target="_blank">Planet F1</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="http://www.cricket365.com/" class="site-footer__link" target="_blank">Cricket365</a>
#             </li>
#                     </ul>
#         </div>
#       </li>
#           <li class="site-footer__col accordian__item" id="site-footer-channels-group>">
#         <a href="#" class="site-footer__head accordian__item-head" aria-controls="site-footer-channels" id="site-footer-channels">Sky Sports Channels</a>
#
#         <div class="accordian__item-content-frame" aria-labelledby="site-footer-channels" id="site-footer-channels-nav">
#           <ul class="site-footer__nav site-footer__nav--vertical accordian__item-content">
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-main-event" class="site-footer__link">Sky Sports Main Event</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-premier-league" class="site-footer__link">Sky Sports Premier League</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-football" class="site-footer__link">Sky Sports Football</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-cricket" class="site-footer__link">Sky Sports Cricket</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-golf" class="site-footer__link">Sky Sports Golf</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-racing" class="site-footer__link">Sky Sports Racing</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-f1" class="site-footer__link">Sky Sports F1 </a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-action" class="site-footer__link">Sky Sports Action</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-arena" class="site-footer__link">Sky Sports Arena </a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-news" class="site-footer__link">Sky Sports News</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/watch/sky-sports-mix" class="site-footer__link">Sky Sports Mix</a>
#             </li>
#                     </ul>
#         </div>
#       </li>
#           <li class="site-footer__col accordian__item" id="site-footer-sky-sites-group>">
#         <a href="#" class="site-footer__head accordian__item-head" aria-controls="site-footer-sky-sites" id="site-footer-sky-sites">More Sky Sites</a>
#
#         <div class="accordian__item-content-frame" aria-labelledby="site-footer-sky-sites" id="site-footer-sky-sites-nav">
#           <ul class="site-footer__nav site-footer__nav--vertical accordian__item-content">
#                       <li class="site-footer__item">
#               <a href="https://www.sky.com/" class="site-footer__link" target="_blank">Sky.com</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="http://news.sky.com/" class="site-footer__link" target="_blank">Sky News</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="https://www.skygroup.sky" class="site-footer__link" target="_blank">Sky Group</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="https://business.sky.com/" class="site-footer__link" target="_blank">Sky For Businesses</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="/workatskysports" class="site-footer__link">Work @ Sky Sports</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="http://www.nowtv.com/promo/sky-sports?dcmp=ilc_SSNTV_skysports_hardcode_footer" class="site-footer__link" target="_blank">NOW TV</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="https://communaltv.sky.com/" class="site-footer__link" target="_blank">Sky Communal TV</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="https://www.skygroup.sky/corporate/bigger-picture" class="site-footer__link" target="_blank">Bigger Picture</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="http://www.sky.com/shop/store-locator/" class="site-footer__link" target="_blank">Store Locator</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="https://www.skymedia.co.uk/?utm_source=Sky_Sports&utm_medium=Web_page&utm_content=Sky_Sports_web_page&utm_campaign=Sky_Sports_web_page" class="site-footer__link" target="_blank">Advertise With Us</a>
#             </li>
#                       <li class="site-footer__item">
#               <a href="https://accessories.sky.com/" class="site-footer__link" target="_blank">Sky TV Accessories</a>
#             </li>
#                     </ul>
#         </div>
#       </li>
#
#     </ul>
#     <!-- / LINKS GRID -->
#
#     <ul class="site-footer__nav site-footer__nav--horizontal-nav">
#           <li class="site-footer__item site-footer__item--inline">
#         <a href="https://www.sky.com/help/articles/skycom-terms-and-conditions" class="site-footer__link" target="_blank">Terms &amp; Conditions</a>
#       </li>
#           <li class="site-footer__item site-footer__item--inline">
#         <a href="https://www.sky.com/help/articles/sky-privacy-and-cookies-notice" class="site-footer__link" target="_blank">Privacy &amp; Cookies Notice</a>
#       </li>
#           <li class="site-footer__item site-footer__item--inline">
#         <a href="#privacy-options" class="site-footer__link">Privacy Options</a>
#       </li>
#           <li class="site-footer__item site-footer__item--inline">
#         <a href="https://www.skyaccessibility.sky/" class="site-footer__link" target="_blank">Accessibility Information</a>
#       </li>
#           <li class="site-footer__item site-footer__item--inline">
#         <a href="/contact-us" class="site-footer__link">Contact Us</a>
#       </li>
#         </ul>
#
#     <p class="site-footer__copyright">
#       <a href="https://www.skysports.com" class="svg-logo site-footer__site-logo">
#         <img class="svg-logo__image" src="https://e1.365dm.com/tvlogos/channels/Sky-Sports-Logo.svg" onerror="this.onerror=null;this.src='https://e1.365dm.com/tvlogos/channels/Sky-Sports-Logo.png'">
#       </a>
#       &copy;2021 Sky UK
#     </p>
#   </div>
# </div>
# <div class="callfn"
#      data-fn="sdc-site-consent-management"
#      data-lite="true"
#      data-spv2="true"
#      data-component-name="sdc-site-consent-management"
#      data-campaign-id="2370"
#      data-privacy-manager-id="157602"
#      data-selector=".site-footer a[href='#privacy-options']"></div>
# <!-- / SITE FOOTER -->
# <link rel="stylesheet" href="/common/styles/project-base-vars.css" type="text/css">
#     <script src="/static/require-2.1.0-15f03d8ff7a4b.js"></script>
#     <script src="/static/include-d91f363fba565d07b7eb760f9c9acd1e-b5a64659e3025.js"></script>
#     <script>
#
#         require.config({"shim":{"facebook-sdk":{"exports":"FB"}},"baseUrl":"/","paths":{"skysports_com":"static/skysports_com-e94d57842da5d","skysports_digrev":"static/skysports_digrev-bcefc920652e7","skysports_legacy":"static/skysports_legacy-8472f78da6ff1","skysports_ipad_components":"static/skysports_ipad_components-9347556046b82","skysports_sap":"core/js/../static/js/skysports_sap","requireLib":"static/require-2.1.0-15f03d8ff7a4b","class":"static/class-55bbf080a62c3","countdown":"static/countdown-3c7569426f127","energize":"static/energize-bac53226fb-9795bcfacb255","hammer":"static/hammer-a592776ebb-f14662ea8bb34","marker-clusterer":"static/marker-clusterer-8a934d664ede6","moment":"static/moment-1.7.2-33075cfd4ad32","reqwest":"static/reqwest-a845dfd832-dea6ebed2de7d","scroll-pane":"static/ftscroller-280c6900bc-ca9da74da3fb9","underscore":"static/lodash.custom-80970c5a1825d","adaptive-content":"static/adaptive-content-1fc383fae518a","article-widget-betting":"static/article-widget-betting-7a9641160b027","app-bridge":"static/app-bridge-30b975666386a","article-advert":"static/article-advert-fa40febcc7b0f","article-outbrain":"static/article-outbrain-bba64c5034e96","autocomplete":"static/autocomplete-62886d6993248","autocomplete-lite":"static/autocomplete-lite-c397d58384aeb","accordian":"static/accordian-87ec71ccbfdd1","betting-lines":"static/betting-lines-31e5cdbecf2bc","bskyb-omniture":"static/bskyb-omniture-de3e9caef9fce","bskyb-omniture-1-2":"static/bskyb-omniture-1.2-ef8627d226d42","calendar-url-builder":"static/calendar-url-builder-863fca999d8c8","carousel":"static/carousel-cfdab6400e999","carousel-lite":"static/carousel-lite-520eccc372b67","close-me":"static/close-me-1dd5bf41462eb","content-stream":"static/content-stream-4ceef3bbd096b","content-swap":"static/content-swap-bdbe29a70d8f9","countdown-widget":"static/countdown-widget-459a93f477481","comments-reply":"static/comments-reply-81d5853bdd03b","cookie":"static/cookie-072824b3a5047","android-notice":"static/android-notice-58d95f174579a","create-audio":"static/create-audio-f77436036a203","create-video":"static/create-video-f5fe547b889be","create-video2":"static/create-video2-bb132ac918d30","dataset":"static/dataset-487d6875fe94d","datepicker":"static/datepicker-b112a28bd151b","datepicker2":"static/datepicker2-d10188465db39","dom":"static/dom-f554c2354ab77","dropdown":"static/dropdown-de4729ed67884","dropdown-select":"static/dropdown-select-bbaa962ff8888","edigital-survey":"static/edigital-survey-6.0.6.0-13762d4026255","element-listener":"static/element-listener-39391d1341a3c","environment":"static/environment-d24a016d1c736","events":"static/events-e6bde13ac56dc","facebook-sdk":"//connect.facebook.net/en_US/all","form":"static/form-269f9f014d35a","form-chart":"static/form-chart-8e3b2b92c7e77","form-validation":"static/form-validation-76d631ee9c0fb","html-poller":"static/html-poller-db12e18d06d04","implicit-personalisation-display":"static/implicit-personalisation-display-2bc93246729e4","implicit-personalisation-storage":"static/implicit-personalisation-storage-a4eb341b47077","implicit-personalisation-removal":"static/implicit-personalisation-removal-7556598e29ff5","inverted-listener":"static/inverted-listener-07a7ace73331d","iscroll-lite":"static/iscroll-lite-03ad473f62d1a","keyboard-listener":"static/keyboard-listener-f6b30a391df5b","keyboard-view":"static/keyboard-view-5a68be0e6dc00","lazy-images":"static/lazy-images-f5238f2864a52","live-article":"static/live-article-95ba706f060b3","live-cricket":"static/live-cricket-98d8debeb2633","live-sport":"static/live-sport-77265bd8792ec","live-update":"static/live-update-945d95543ad61","live-refresh":"static/live-refresh-5ebefb5206c82","live-refresh-darts-table-controller":"static/live-refresh-darts-table-controller-d6c7bb8af0efe","live-refresh-darts-table-view":"static/live-refresh-darts-table-view-5c4f5e87a3cb2","live-refresh-football-controller":"static/live-refresh-football-controller-461aca93a03fe","live-refresh-football-vie ...
#
#         require(['skysports_digrev', 'sdc-site-pub-sub'], function (appController, pubsub) {
#             window.sdc = window.sdc || {};
#             pubsub.init(window.sdc);
#
#             appController.init();
#         });
#
#     </script>
# <script type="text/javascript">//<![CDATA[
#     _uzactions = window._uzactions || [];
#     _uzactions.push(['_setID', 'A8C553219B93EA11AA5EC9768AD49726']);
#     _uzactions.push(['_setSID', 'BCECC91A9B93EA11AA5EC9768AD49726']);
#     _uzactions.push(['_start']);
#     (function() {
#         var uz = document.createElement('script'); uz.type = 'text/javascript'; uz.async = true; uz.charset = 'utf-8';
#         uz.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdn4.userzoom.com/trueintent/js/uz_til.js?cuid=B586ADA60ECEE411B0190022196C2B88';
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(uz, s);
#     })();
#     //]]></script>        <script src="/static/require-2.1.0-15f03d8ff7a4b.js" type="text/javascript"></script>
#     <script>
# SKY_SPORTS.deferred(function () {
#
#     var st_tag = document.createElement('script');
#     st_tag.async = true;
#     st_tag.src = "//native.sharethrough.com/assets/tag.js";
#     document.getElementsByTagName('head')[0].appendChild(st_tag);
#
# });
# </script>
# <script src='https://cloud-static.storage.googleapis.com/production/widgets/mk2/js/common/generator.min.js' async></script><script type="text/javascript">window.ocEnv={url:window.location.href,};</script><script>
#     SKY_SPORTS.deferred(function(){
#         require(['bskyb-omniture'], function (bskybOmniture) {
#
#             var aamGetCookie =  function (c_name)
#             {
#                 var i, x, y, c = document.cookie.split(";");
#                 for (i = 0; i < c.length; i++)
#                 {
#                     x = c[i].substr(0, c[i].indexOf("="));
#                     y = c[i].substr(c[i].indexOf("=") + 1);
#                     x = x.replace(/^\s+|\s+$/g, "");
#                     if (x == c_name)
#                     {
#                         return unescape(y);
#                     }
#                 }
#             };
#
#             var tracking = '';
#             var cookie = aamGetCookie("interactive");
#             var interactive = (cookie) ? JSON.parse(cookie) : {};
#             if( 'undefined' !== typeof interactive.tid ) {
#                 tracking = interactive.tid;
#             }
#
#             var omnitureInitiated = false;
#
#             var initAnalytics = function(targetData) {
#
#                 if(omnitureInitiated) {
#                     return;
#                 }
#
#                 omnitureInitiated = true;
#
#                 var omnitureData = {
#                     trackingId: tracking,
#                     site: "sky/portal/sports",
#                     section: "football/barclays_premier_league",
#                     contentType: "table",
#                                         contentId: "",
#                     sport: "Football",                    account: "bskybsports"
#                 };
#
#
#                 if(typeof targetData !== "undefined" && targetData.tntVal) {
#                     omnitureData.tnt = targetData.tntVal;
#                 }
#
#                 // site-wide analytics
#                 bskybOmniture.init(omnitureData);
#             };
#
#             if(window.sdc && window.sdc.pubSub) {
#                 window.sdc.pubSub.subscribe('dynamic-tile.events.adobe-target-fetched', function(data) {
#                     initAnalytics(data);
#                 });
#             }
#
#             setTimeout(initAnalytics, 2000);
#
#         });
#     });
#
#     var s_account = "bskybsports";
# </script>
#
#
#   <script type="text/javascript">_satellite.pageBottom();</script>
#
#           <script>
#       var _sf_async_config = _sf_async_config || {};
#       _sf_async_config.sections = 'type:table,premier league,football';
#
#
#     window._sf_endpt = new Date().getTime();
#     var script = document.createElement('script');
#     script.src = document.location.protocol + '//static.chartbeat.com/js/chartbeat.js';
#     document.body.appendChild(script);
#   </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam-cell.nr-data.net","licenseKey":"517f0b291f","applicationID":"545304393","transactionName":"blcEMUpZCxdYV0MIXVcdJRBLTAoJFlJYDkZbUwoJF1sKCk1GWA1eXEAVSntXCBRcQF4VW1ZcFSZXVhEWVlhbBEAXQg4V","queueTime":0,"applicationTime":347,"atts":"QhATRwJDGEgbVRVbSURP","errorBeacon":"bam-cell.nr-data.net","agent":""}</script></body>
# </html>

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page.text , 'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Premier League Table &amp; Standings - Sky Sports Football</title>
# <meta content="NOODP,INDEX,FOLLOW" name="robots">
# <meta content="Complete table of Premier League standings for the 2011/2012 Season, plus access to tables from past seasons and other Football leagues." name="description"/>
# <meta content="Sky, Sports, Football, News, Premier, League, Fixtures, Results, Tables, Photos, Transfer, Centre, Arsenal, Aston Villa, Birmingham City, Blackburn Rovers, Bolton Wanderers, Burnley, Chelsea, Everton, Fulham, Hull City, Liverpool, Manchester City, Man City, Manchester United, Man Utd, Portsmouth, Stoke City, Sunderland, Tottenham Hotspur, Spurs, West Ham, Wigan Athletic, Wolverhampton Wanderers, Wolves, watch, video, live, pc. torress, benitez" name="keywords"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"517f0b291f",applicationID:"545304393"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(8),f=t(9),c=t("ee").get("tracer"),u=t("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(t,e){s[e]=i(p+e,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),t,n],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],n),t}finally{c.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(l+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){function r(){return f.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,f=t(10);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],4:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],5:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof m&&!g){var e=Math.round(t.timeStamp),n={type:t.type};e<=p.now()?n.fid=p.now()-e:e>p.offset&&e<=Date.now()?(e-=p.offset,n.fid=p.now()-e):e=p.now(),g=!0,d("timing",["fi",e,n])}}function f(t){d("pageHide",[p.now(),t])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var c,u,s,d=t("handle"),p=t("loader"),l=t(7),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){c=new PerformanceObserver(r);try{c.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,h=["click","keydown","mousedown","pointerdown","touchstart"];h.forEach(function(t){document.addEventListener(t,a,!1)})}l(f)}},{}],6:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}e.exports={agent:i,version:o,match:r}},{}],7:[function(t,e,n){function r(t){function e(){t(a&&document[a]?do ...
# <link href="//e0.365dm.com" rel="dns-prefetch"/>
# <link href="//e1.365dm.com" rel="dns-prefetch"/>
# <link href="//e2.365dm.com" rel="dns-prefetch"/>
# <link href="//fresh8.co" rel="dns-prefetch"/>
# <link href="//annex.fresh8.co" rel="dns-prefetch"/>
# <link href="//cdn-gs.fresh8.co" rel="dns-prefetch"/>
# <link href="//player.ooyala.com" rel="dns-prefetch"/>
# <link href="//static.chartbeat.com" rel="dns-prefetch"/>
# <link href="//assets.adobedtm.com" rel="dns-prefetch"/>
# <link href="//img.skysports.com" rel="dns-prefetch"/>
# <link href="//video.skysports.com" rel="dns-prefetch"/>
# <link href="//cdn.livefyre.com" rel="dns-prefetch"/>
# <link href="//app-cdn.spot.im" rel="dns-prefetch"/>
# <link href="//cdn.teads.tv" rel="dns-prefetch"/>
# <link href="//services.babator.com" rel="dns-prefetch"/>
# <link href="//eu-services.babator.com" rel="dns-prefetch"/>
# <link href="//widgets.oddschecker.com" rel="dns-prefetch"/>
# <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//metrics-api.librato.com" rel="dns-prefetch"/>
# <link href="//cloud-static.storage.googleapis.com" rel="dns-prefetch"/>
# <link href="//analytics.ooyala.com" rel="dns-prefetch"/>
# <link href="//l.ooyala.com" rel="dns-prefetch"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="Sky Sports" name="apple-mobile-web-app-title"/>
# <meta content="SkySports" name="application-name"/>
# <meta content="width=device-width,maximum-scale=1,minimum-scale=1,minimal-ui" id="viewport" name="viewport"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="GeOj3ib0hXB5Iewz4HWUfve0FidZUHpPXlBi6oPOTjU" name="google-site-verification">
# <meta content="10911153761" property="fb:pages"><meta content="509247152,100000206570823" property="fb:admins">
# <meta content="Premier League (Sky Sports)" property="og:title">
# <meta content="https://www.skysports.com/premier-league-table/2011" property="og:url">
# <meta content="Get the latest Premier League Football news, fixtures, results, video and more from Sky Sports." property="og:description">
# <meta content="SkySports" property="og:site_name">
# <script>
# if ((/iPad|iPhone|iPod/).test(navigator.userAgent)) {
#     var headNode = document.getElementsByTagName('head')[0];
#     var sbNode = document.createElement('meta');
#     sbNode.name = 'apple-itunes-app';
#     sbNode.content = 'app-id=500102120';
#     headNode.appendChild(sbNode);
# }
# </script>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed">
# <style data-webfont-src="/static/skytext-reg-bce1c746d381a.css"></style>
# <style data-webfont-src="/static/skytext-med-c849e3d033da4.css"></style>
# <style data-webfont-src="/static/skycons-baae5a5793309.css"></style>
# <link href="/static/skysports-digrev-b2b2f1ef15554.css" media="all" rel="stylesheet" title="default" type="text/css">
# <!--[if IE 8]>
#         <link rel="stylesheet" type="text/css" href="/static/skysports-digrev-ie8-b40bc63c79e5f.css">
#     <![endif]-->
# <script data-grade-b-src="/static/head-grade-b-6a22e81a4779c.js" data-grade-c-src="/static/head-grade-c-a4c5458d881fc.js" id="script-polyfills"></script>
# <script>// google ads set up
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         googletag.adSlots = {};</script>
# <script type="text/javascript">
#       var _sf_async_config = _sf_async_config || {};
#       _sf_async_config.uid = '43610';
#       _sf_async_config.domain = 'skysports.com';
#       _sf_async_config.flickerControl = false;
#       _sf_async_config.useCanonical = true;
#   </script>
# <script>window.SKY_SPORTS = window.SKY_SPORTS || {
#     deferedFunctionsCalled: !1,
#     deferredArray: [],
#     deferred: function(e) {
#         this.deferredArray.push(e);
#     },
#     callDeferredFunctions: function() {
#         if (!this.deferedFunctionsCalled) {
#             for (var e = -1; ++e < this.deferredArray.length; ) this.deferredArray[e] && this.deferredArray[e].call();
#             this.deferedFunctionsCalled = !0;
#         }
#     },
#     initIframeWidget: function(t) {
#         window.addEventListener("message", function(e) {
#             t.style.height = e.data + "px";
#         });
#     }
# }, function() {
#     window.aab = window.aab || {}, aab.playerLoaded = function(y) {
#         y = y || "OO", aab.playerLoadedCalled = y, window[y].aabPluginLoaded || window[y].plugin("AAB", function(S, e, t, n) {
#             aab.addingPlugin = !0, aab.OO = S;
#             return function(t, e) {
#                 var i, a, n, o, r, s, d = !(window[y].aabPluginLoaded = !0), c = !1, l = 3e4, u = 1e3;
#                 function m() {
#                     var e = new Date().getTime();
#                     o = o || e, d || (null == n || S.supportsFlash) && (c && !r || (!s && n.error && f(0, n.error),
#                     l < e - o ? p() : setTimeout(m, u)));
#                 }
#                 function p() {
#                     function e() {
#                         var e = document.createElement("div");
#                         e.style.height = "100%", e.style.backgroundColor = "#000", e.style.color = "#999",
#                         e.style.textAlign = "center", e.innerHTML = "<br><br>An error occurred when loading the player.<br>Please review your connection settings and try again.",
#                         document.getElementById(i).innerHTML = "", document.getElementById(i).appendChild(e);
#                     }
#                     n.destroy(), t.subscribe(S.EVENTS.DESTROY, "aab", e), e();
#                 }
#                 function f(e, t) {
#                     s = t && "cannotDownloadThirdPartyModule" === t.code && "flash" === t.source;
#                 }
#                 function h() {
#                     d = !0;
#                     var a = console.error;
#                     console.error = function() {
#                         a.apply || Function.prototype.apply.apply(a, [ console, arguments ]), a.apply(console, arguments);
#                         var e = arguments && 0 < arguments.length ? arguments[0] : "";
#                         if (e.match(/Error\: Ad adLoadError/i)) {
#                             var t = document.getElementById(i).getElementsByTagName("object"), n = null;
#                             t && (1 == t.length ? n = t[0] : 2 == t.length && (n = t[1])), n && (e.match(/errorCode\: 1001/i) ? n.adLoadEmptyVast && n.adLoadEmptyVast() : n.adLoadError && n.adLoadError());
#                         }
#                     };
#                 }
#                 function w() {
#                     !n && S.supportsFlash && (n = S.players[i]) && (t.subscribe("aabLoaded", "aab", h),
#                     t.subscribe("aabBlocked", "aab", p), t.subscribe("preDetectionComplete", "aab", function() {}),
#                     t.subscribe("noAdBlockerDetected", "aab", function() {}), t.subscribe("adBlockerDetected", "aab", function() {}),
#                     setTimeout(m, u));
#                 }
#                 S.supportsFlash && (t.subscribe(S.EVENTS.PLAYER_CREATED, "aab", function(e, t, n) {
#                     i = t, a = n;
#                 }), t.subscribe(S.EVENTS.PLAYER_EMBEDDED, "aab", w), t.subscribe(S.EVENTS.METADATA_FETCHED, "aab", function(e, t) {
#                     for (var n in w(), c = !0, r = !!t.base.aabEnabled && "true" === t.base.aabEnabled,
#                     function() {
#                         if (!r) {
#                             var e = "anti-adblocker";
#                             a.devModuleURL && a.devModuleURL.toLowerCase().indexOf("aabadsmanager.swf") && (e = "dev-other"),
#                             a[e] && a[e].aab && a[e].aab.aabEnabled && (r = !0);
#                         }
#                     }(), t.modules) ;
#                 }), t.subscribe(S.EVENTS.ERROR, "aab", f));
#             };
#         });
#     };
#     var n = [ "OO", "OoyalaPlayer1", "OoyalaPlayer2", "OoyalaPlayer3", "OoyalaPlayer4", "OoyalaPlayer5", "OoyalaPlayer6", "OoyalaPlayer7", "OoyalaPlayer8" ];
#     function e() {
#         aab.onReadyCalled = !0;
#         for (var e = 0; e < n.length; e++) {
#             var t = n[e];
#             if (window[t]) {
#                 aab.namespaceFound = t, aab.playerLoaded(t);
#                 break;
#             }
#         }
#     }
#     document.addEventListener ? (aab.eventListenerType = "addEventListener", document.addEventListener("DOMContentLoaded", e)) : document.attachEvent && (aab.eventListenerType = "attachEvent",
#     aab.onreadystatechangeFired = !1, document.attachEvent("onreadystatechange", function() {
#         aab.onreadystatechangeFired = !0, "complete" === document.readyState && (document.detachEvent("onreadystatechange", arguments.callee),
#         e());
#     })), e();
# }(), function() {
#     for (var i = 0, e = [ "moz", "webkit" ], t = 0; t < e.length && !window.requestAnimationFrame; ++t) window.requestAnimationFrame = window[e[t] + "RequestAnimationFrame"],
#     window.cancelAnimationFrame = window[e[t] + "CancelAnimationFrame"] || window[e[t] + "CancelRequestAnimationFrame"];
#     window.requestAnimationFrame || (window.requestAnimationFrame = function(e) {
#         var t = new Date().getTime(), n = Math.max(0, 16 - (t - i)), a = window.setTimeout(function() {
#             e(t + n);
#         }, n);
#         return i = t + n, a;
#     }), window.cancelAnimationFrame || (window.cancelAnimationFrame = function(e) {
#         clearTimeout(e);
#     });
# }(), function() {
#     var e = document.createElement("div");
#     e.setAttribute("data-a", "b"), e.className = "a";
#     var t = document.getElementById("script-polyfills");
#     t && ("addEventListener" in window && Function.prototype.bind && String.prototype.trim && "textContent" in e && Array.prototype.indexOf || document.write("<script src='" + t.getAttribute("data-grade-c-src") + "'><\/script>"),
#     "classList" in e && "dataset" in e || document.write("<script src='" + t.getAttribute("data-grade-b-src") + "'><\/script>"));
# }(), SKY_SPORTS.getUa = function(t) {
#     function e(e) {
#         return !!t.match(e) && parseFloat(t.match(e)[1].replace("_", "."));
#     }
#     var n = !1;
#     null !== new RegExp("MSIE ([0-9]{1,}[.0-9]{0,})").exec(t) && (n = parseFloat(RegExp.$1));
#     var a = t.match(/iPad/), i = t.match(/iP/), o = t.match(/android/i), r = t.match(/windows phone/i), s = navigator.platform.match(/mac|win/i), d = {
#         classList: ""
#     };
#     return r && ((d = {
#         mobile: !0,
#         windowsphone: !0,
#         name: "windowsphone",
#         version: e(/os ([0-9]\.[0-9])/i) || e(/windows phone ([0-9]\.[0-9])/i)
#     }).classList = [ d.name, d.name + d.version, "mobile" ].join(" ")), n && ((d = {
#         msie: !0,
#         name: "msie",
#         version: n
#     }).classList = [ d.name, d.name + d.version ].join(" ")), (a || i) && ((d = {
#         ios: !0,
#         name: a ? "ipad" : "iphone",
#         mobile: !0,
#         version: e(/os ([1-9]\_[0-9])/i)
#     }).classList = [ d.name, d.name + d.version, d.device, "ios", "ios" + d.version, "mobile" ].join(" ")),
#     o && ((d = {
#         android: !0,
#         name: "android",
#         mobile: !0,
#         version: e(/android ([1-9]\.[0-9])/i)
#     }).classList = [ d.name, d.name + d.version, "mobile" ].join(" ")), s && (d.desktop = !0,
#     d.classList += " desktop"), d;
# }, SKY_SPORTS.getFeatures = function(n, e) {
#     function t(e, t) {
#         return n.classList += t ? " " + e : " no-" + e, t;
#     }
#     e.style.cssText = "-webkit-animation-name:shim;animation-name:shim;-moz-animation-name:shim;width:10vw",
#     n.hasTouch = t("touch", "ontouchstart" in window || "DocumentTouch" in window && document instanceof window.DocumentTouch),
#     n.hasSvg = t("svg", !!document.implementation.hasFeature("http://www.w3.org/TR/SVG11/feature#BasicStructure", "1.1")),
#     n.hasCssAnimations = t("cssanimations", !!(e.style.animationName || e.style.webkitAnimationName || e.style.mozAnimationName)),
#     n.hasVpUnits = t("vpunits", !!e.style.width), n.hasWebWorkers = t("web-workers", !!window.Worker);
#     var a = {
#         webkitAnimation: "webkitAnimationStart",
#         mozAnimation: "mozAnimationStart",
#         animation: "animationstart",
#         msAnimation: "MSAnimationStart"
#     };
#     for (var i in a) i in e.style && (n.animationEventName = a[i]);
#     return n;
# }, SKY_SPORTS.device = SKY_SPORTS.getUa(navigator.userAgent), SKY_SPORTS.getFeatures(SKY_SPORTS.device, document.createElement("div")),
# document.documentElement.className = "js " + SKY_SPORTS.device.classList, function(t, e) {
#     t.SKY_SPORTS = t.SKY_SPORTS || {}, localStorage.removeItem("jscss");
#     var n = e.createElement("style"), a = "ss.js.styles", i = {}, o = t.localStorage.getItem(a);
#     function r() {
#         var e = function() {
#             var e = "";
#             for (var t in i) e += i[t];
#             return e;
#         }();
#         n.styleSheet ? n.styleSheet.cssText = e : n.textContent = e, t.localStorage.setItem(a, JSON.stringify(i));
#     }
#     n.id = a, e.getElementsByTagName("head")[0].appendChild(n), o && (i = JSON.parse(o)),
#     r(), t.SKY_SPORTS.addCss = function(e) {
#         e.id in i != 0 && i[e.id] === e.css || (i[e.id] = e.css), r();
#     }, t.SKY_SPORTS.removeCss = function(e) {
#         e in i && delete i[e], r();
#     };
# }(window, document), function(r) {
#     function s(e, t) {
#         t.match("font-family: 'SkyTextMed'") && (t += t.replace("font-family: 'SkyTextMed'", "font-weight: 600; font-family: 'skytext'")),
#         t.match("font-family: 'SkyTextReg'") && (t += t.replace("font-family: 'SkyTextReg'", "font-weight: 400; font-family: 'skytext'")),
#         e.styleSheet ? e.styleSheet.cssText = t : e.textContent = t;
#     }
#     SKY_SPORTS.getFont = function(t, e) {
#         if ("keys" in Object != !1) {
#             var n, a;
#             n = e.split("/").pop(), (a = n.split("-")).splice(-1), a = a.join("-");
#             var i = r.localStorage.getItem(n);
#             if (i) s(t, i); else {
#                 Object.keys(r.localStorage).forEach(function(e) {
#                     e.match(a) && r.localStorage.removeItem(e);
#                 });
#                 var o = new XMLHttpRequest();
#                 o.onreadystatechange = function() {
#                     if (4 === this.readyState && 200 === this.status) {
#                         var e = this.responseText;
#                         s(t, e), r.localStorage.setItem(n, e);
#                     }
#                 }, o.open("GET", e, !0), o.send();
#             }
#         }
#     };
#     for (var e = document.querySelectorAll("style[data-webfont-src]"), t = -1; ++t < e.length; ) SKY_SPORTS.getFont(e[t], e[t].getAttribute("data-webfont-src"));
# }(window), function(t, n) {
#     "use strict";
#     if (n.currentBreakPoint = 10, n.currentAdvertBreakPoint = "display", n.getBreakPoint = function() {
#         var e = t.getComputedStyle(n.body, ":after").getPropertyValue("content");
#         return e = parseInt(e.replace(/['"]/g, ""), 10);
#     }, n.getAdvertBreakPoint = function() {
#         return t.getComputedStyle(n.body, ":before").getPropertyValue("content").replace(/['"]/g, "");
#     }, Function.prototype.debounce = function(e) {
#         var t = this;
#         return function() {
#             t.args = arguments, t.timeout_id && clearTimeout(t.timeout_id), t.timeout_id = setTimeout(function() {
#                 return t.apply(t, t.args);
#             }, e);
#         };
#     }, n.createEvent) {
#         var a = n.createEvent("Event");
#         a.initEvent("breakPointChange", !0, !0);
#         var i = n.createEvent("Event");
#         i.initEvent("advertChange", !0, !0), t.addEventListener("DOMContentLoaded", function() {
#             n.currentBreakPoint = n.getBreakPoint(), n.currentAdvertBreakPoint = n.getAdvertBreakPoint();
#         }, !1), t.addEventListener("resize", function() {
#             var e = n.getBreakPoint(), t = n.getAdvertBreakPoint();
#             e !== n.currentBreakPoint && (n.currentBreakPoint = e, n.dispatchEvent(a)), t !== n.currentAdvertBreakPoint && (n.currentAdvertBreakPoint = t,
#             n.dispatchEvent(i));
#         }.debounce(300), !1);
#     }
# }(window, document), function() {
#     function s(e) {
#         for (var t = document.cookie.split(";"), n = -1; ++n < t.length; ) {
#             var a = t[n].split("=");
#             if (a[0].match(e)) return decodeURIComponent(a[1]);
#         }
#         return "";
#     }
#     function d() {
#         var e = window.SKY_SPORTS.user;
#         return e.isLoggedIn ? e.isSkySports ? 1 : e.isWholesale ? 3 : 4 : 2;
#     }
#     window.SKY_SPORTS = window.SKY_SPORTS || {}, function e() {
#         var t, n, a = s("interactive"), i = a ? JSON.parse(a) : {}, o = s("skySportsSSO"), r = {
#             isLoggedIn: (t = o, !!t),
#             getType: d,
#             set: e
#         };
#         r.isLoggedIn && (r.name = i.f || "", r.isSkyHD = 1 === i.hd, r.isSky = 1 === i.st,
#         r.isSkySports = 2 === i.st, r.isNowTV = 3 === i.st, r.isWholesale = !(!(n = o) || !n.match(/^WIG/))),
#         window.SKY_SPORTS.user = r, function(e) {
#             var t = e.getType(), n = 1 === t || 3 === t ? '.item[data-role="nosub"]{display:none!important}.item[data-role="sub"]{display:inline-block!important}' : '.item[data-role="sub"] {display:none!important}';
#             n += 1 !== t || e.isWholesale ? "" : ".remote-record-link.-hdn {display:block!important}";
#             var a = e.isWholesale ? "[data-not-for-wholesale]{display:none!important}" : "";
#             window.SKY_SPORTS.addCss({
#                 id: "userTypeButton",
#                 css: '.button[data-role="subscriber-promo-button"]:after{content:attr(data-usertype' + t + ")}" + n + a
#             }), window.SKY_SPORTS.addCss({
#                 id: "userLabel",
#                 css: ".user-label:after{content:attr(data-label-type" + t + ")}"
#             });
#         }(window.SKY_SPORTS.user);
#     }();
# }(), SKY_SPORTS.postpone = {
#     funcs: {},
#     init: function() {
#         this.items = document.getElementsByClassName("postpone"), this.addFunc("removeclass", function() {
#             var e = this.getAttribute("data-postpone-removeclass");
#             e && this.classList.remove(e), this.classList.remove("postpone");
#         }), this.scan();
#     },
#     addFunc: function(e, t) {
#         this.funcs[e] = t;
#     },
#     scan: function() {
#         for (var e = -1; ++e < this.items.length; ) {
#             var t, n = this.items[e];
#             n.whenVisible || (t = n.getAttribute("data-postpone-call")) && this.funcs[t] && (n.whenVisible = this.funcs[t],
#             n.setAttribute("data-postpone-class", this.className), n.detach = this.detach),
#             this.isInViewPort(n) && n.whenVisible();
#         }
#         var a = this;
#         setTimeout(function() {
#             window.requestAnimationFrame(a.scan.bind(a));
#         }, 50);
#     },
#     isInViewPort: function(e) {
#         var t = e.getBoundingClientRect();
#         return 0 !== t.width && (!(t.bottom < 0) && !(window.innerHeight - t.top < 0));
#     }
# }, SKY_SPORTS.postpone.init();</script>
# <script src="//assets.adobedtm.com/launch-ENd3e4df0dfde7473d823092cac7cd0611.min.js"></script>
# <script type="text/javascript">
#         !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
#     </script>
# <script>
#         window._sp_ = {
#             config: {
#                 accountId: 630,
#                 propertyId: 2370,
#                 wrapperAPIOrigin: "https://wrapper-api.sp-prod.net/tcfv2",
#                 mmsDomain: "https://message630.sp-prod.net",
#
#             }
#         }
#     </script>
# <script src="https://gdpr-tcfv2.sp-prod.net/wrapperMessagingWithoutDetection.js"></script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# </link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body>
# <div class="site-header">
# <div class="site-header__body">
# <div class="site-header__col site-header__col1">
# <a class="svg-logo site-header__logo" href="https://www.skysports.com">
# <img class="svg-logo__image" onerror="this.onerror=null;this.src='/core/img/channels/Sky-Sports-Logo.png'" src="/core/img/channels/Sky-Sports-Logo-transparent.svg"/>
# </a>
# </div>
# <div class="site-header__col site-header__col2">
# <div class="site-login callfn" data-fn="skyid-login" data-lite="true">
# <script class="login-text" data-role="default" type="text/template">
#                 <!--default-->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo"><a href="https://www.skysports.com/watch/get-sky" class="site-login__link">Get Sky Sports</a></li>
#                     <li class="site-login__item"><a class="site-login__link site-login__link--user callfn" href="https://skyid.sky.com/signin/sports?successUrl=https%3A%2F%2Fwww.skysports.com%2Fpremier-league-table%2F2011" data-mobile-url="/sso/signin/mobile" data-desktop-url="/sso/signin/desktop" data-lite="true" >Log In</a></li>
#                 </ul>
#             </script>
# <script class="login-text" data-role="isSkySports" type="text/template">
#                 <!-- sky sports user logged in -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2011" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#             </script>
# <script class="login-text" data-role="isSky" type="text/template">
#                 <!-- sky sports user logged in -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo">
#                         <a href="/watch/get-sky" class="site-login__link">Upgrade</a>
#                     </li>
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2011" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#             </script>
# <script class="login-text" data-role="isNowTv" type="text/template">
#                 <!-- now tv customer -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo"><a href="https://www.skysports.com/watch/get-sky" class="site-login__link">Get Sky Sports</a></li>
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2011" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#             </script>
# <script class="login-text" data-role="isLoggedIn" type="text/template">
#                 <!-- just a sky id login -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item site-login__item--promo"><a href="https://www.skysports.com/watch/get-sky" class="site-login__link">Get Sky Sports</a></li>
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user">#{name}</span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2011" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#             </script>
# <script class="login-text" data-role="isWholesale" type="text/template">
#                 <!-- wholesale customer -->
#                 <ul class="site-login__links">
#                     <li class="site-login__item"><span class="site-login__link site-login__link--user"></span></li>
#                     <li class="site-login__item"><a href="https://www.skysports.com/signout?url=https://www.skysports.com%2Fpremier-league-table%2F2011" class="site-login__link site-login__link--signout">Log Out</a></li>
#                 </ul>
#             </script>
# </div>
# </div>
# <div class="site-header__col site-header__col3">
# <form action="https://www.skysports.com/search" class="site-search" method="GET">
# <input accesskey="q" autocapitalize="off" autocomplete="off" autocorrect="off" class="site-search__input" name="q" placeholder="Search Sky Sports" type="text"/>
# <input name="searchtype" type="hidden" value="the site"/>
# <input name="v" type="hidden" value="2"/>
# <button class="site-search__button">
# <span class="site-search__button-label">Search</span>
# </button>
# </form>
# </div>
# <a class="site-header__col site-header__col4 site-header__nav-button-hit-area" data-role="open-left-hand-nav" href="#no-js-nav" tabindex="1">
# <svg class="site-header__nav-button" version="1.1" viewbox="0 0 2048 2048" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <rect height="256" width="2048" y="384"></rect>
# <rect height="256" width="2048" y="896"></rect>
# <rect height="256" width="2048" y="1408"></rect>
# </svg>
# </a>
# </div>
# <!-- desktop nav -->
# <div aria-hidden="true" class="site-nav-desktop__wrap adaptive-content callfn" data-fn="adaptive-content" data-lite="true">
# <script type="text/template">
# <div class="site-nav-desktop callfn" role="navigation" data-fn="site-nav-desktop" data-lite="true">
# <ul class="site-nav-desktop__body">
# <li class="site-nav-desktop__item">
# <a href="/" class="site-nav-desktop__item-link">
# Home</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="#site-nav-desktop-sports-more-nav" class="site-nav-desktop__item-link site-nav-desktop__item-link--more" aria-controls="site-nav-desktop-sports-more-nav" id="site-nav-desktop-sports-more">
# Sports</a>
# <div class="site-nav-desktop__menu" aria-labelledby="site-nav-desktop-sports-more" id="site-nav-desktop-sports-more-nav">
# <div class="site-nav-desktop__menu-body">
# <ul class="site-nav-desktop__menu-links">
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/football">
# Football</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/f1">
# F1</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/cricket">
# Cricket</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/rugby-union">
# Rugby Union</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/rugby-league">
# Rugby League</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/golf">
# Golf</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/boxing">
# Boxing</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/nfl">
# NFL</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/olympics">
# Olympics</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/tennis">
# Tennis</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/racing">
# Racing</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/darts">
# Darts</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/nba">
# NBA</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/netball">
# Netball</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/gaa">
# GAA</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/mma">
# MMA</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/more-sports">
# More Sports</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/live-scores" class="site-nav-desktop__item-link">
# Scores</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/watch/video" class="site-nav-desktop__item-link">
# Video</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/watch" class="site-nav-desktop__item-link">
# TV</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="https://www.skybet.com?aff=9749&dcmp=ss_main_nav" class="site-nav-desktop__item-link" target="_blank">
# Sky Bet</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="/games" class="site-nav-desktop__item-link">
# Games</a>
# </li>
# <li class="site-nav-desktop__item">
# <a href="#site-nav-desktop-more-more-nav" class="site-nav-desktop__item-link site-nav-desktop__item-link--more" aria-controls="site-nav-desktop-more-more-nav" id="site-nav-desktop-more-more">
# More</a>
# <div class="site-nav-desktop__menu site-nav-desktop__menu--right" aria-labelledby="site-nav-desktop-more-more" id="site-nav-desktop-more-more-nav">
# <div class="site-nav-desktop__menu-body">
# <ul class="site-nav-desktop__menu-links">
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/transfer-centre">
# Transfer Centre</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/watch/sport-on-sky">
# Live on Sky</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/get-sky?dcmp=gss_more_dropdown">
# Get Sky Sports</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/watch/tv-shows">
# TV Shows</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/watch/tv-guide">
# TV Guide</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.sky.com/shop/tv/sky-go/?dcmp=skygo_ss.com_more" target="_blank">
# Sky Go</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="http://www.nowtv.com/promo/sky-sports?dcmp=ilc_SSNTV_skysports_hardcode_moredropdownlink" target="_blank">
# Now TV</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.kickitout.org/forms/online-reporting-form" target="_blank">
# Kick It Out</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/football/news/topic/8724/black-lives-matter">
# Black Lives Matter</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/podcasts">
# Podcasts</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/mobile">
# Mobile</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://twitter.com/SkySports" target="_blank">
# Twitter</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.facebook.com/SkySports" target="_blank">
# Facebook</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/contact-us">
# Contact Us</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="/workatskysports">
# Work @ Sky Sports</a>
# </li>
# <li class="site-nav-desktop__menu-item">
# <a class="site-nav-desktop__menu-link" href="https://www.sky.com/help/articles/skycom-terms-and-conditions" target="_blank">
# Terms &amp; Conditions</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# <a href="https://www.skysports.com/watch" class="site-nav-desktop__watch-button no-default-hover no-default-active"><span class="site-nav-desktop__watch-button__label">Watch Sky Sports</span></a>
# </div>
# </script>
# </div>
# </div><div id="mobile-bet-basket"></div> <div class="advert--banner-wrap-ghost">
# <div class="advert--banner-wrap">
# <div class="block advert advert--banner">
# <div class="advert__container" id="leaderboard">
# </div>
# </div>
# </div>
# </div>
# <div class="site-wrapper">
# <div class="grid site-layout-primary callfn" data-fn="site-layout-primary" data-lite="true">
# <div class="grid__col site-layout-primary__col1">
# <!-- page title -->
# <div class="page-header">
# <ul class="page-header__breadcrumb">
# <li class="page-header__breadcrumb-item">
# <h2 class="page-header__breadcrumb-title">
# <a class="page-header__breadcrumb-link" href="https://www.skysports.com/football">Football</a>
# </h2>
# </li>
# </ul>
# <h1 class="page-header__title">
# <a class="page-header__title-link" href="/premier-league">
# <abbr class="swap-text--bp30" title="Premier League">
# <span class="swap-text__target">Premier League</span>
# </abbr>
# </a>
# <span class="page-header__title-subitem">Table</span>
# </h1>
# <div class="block page-header__sponsor">
# <div class="advert__container" id="sponsor-position">
# </div>
# </div>
# </div>
# <div class="page-nav callfn" data-fn="page-nav" data-lite="true">
# <a aria-controls="page-nav-control" class="page-nav__head" href="#page-nav" id="page-nav-control">
# <h3 class="page-nav__title">Table</h3>
# <div class="page-nav__title-more"></div>
# </a>
# <div class="page-nav__frame">
# <div aria-labelledby="page-nav" class="page-nav__body" id="page-nav" style=" visibility: hidden;">
# <ul class="page-nav__item-group">
# <li class="page-nav__item">
# <a class="page-nav__link" href="/premier-league-news">News</a>
# </li>
# <li class="page-nav__item page-nav__item--select">
# <select class="page-nav__select callfn" data-fn="implicit-personalisation-display" data-key="football.team" data-label="Your most viewed" data-lite="true" data-name="skysports-implicit-personalisation" onchange="location.href=this.options[selectedIndex].value" tabindex="-1">
# <option disabled="" selected="selected">Select a team</option>
# <option class="page-nav__select-option" id="all-teams" value="/football/teams">All Teams</option>
# <optgroup label="Premier League">
# <option class="page-nav__select-option" data-itemid="413" value="/arsenal">Arsenal</option>
# <option class="page-nav__select-option" data-itemid="238" value="/aston-villa">Aston Villa</option>
# <option class="page-nav__select-option" data-itemid="194" value="/brentford">Brentford</option>
# <option class="page-nav__select-option" data-itemid="212" value="/brighton-and-hove-albion">Brighton</option>
# <option class="page-nav__select-option" data-itemid="160" value="/burnley">Burnley</option>
# <option class="page-nav__select-option" data-itemid="524" value="/chelsea">Chelsea</option>
# <option class="page-nav__select-option" data-itemid="234" value="/crystal-palace">Crystal Palace</option>
# <option class="page-nav__select-option" data-itemid="229" value="/everton">Everton</option>
# <option class="page-nav__select-option" data-itemid="183" value="/leeds-united">Leeds United</option>
# <option class="page-nav__select-option" data-itemid="152" value="/leicester-city">Leicester City</option>
# <option class="page-nav__select-option" data-itemid="155" value="/liverpool">Liverpool</option>
# <option class="page-nav__select-option" data-itemid="345" value="/manchester-city">Manchester City</option>
# <option class="page-nav__select-option" data-itemid="210" value="/manchester-united">Manchester United</option>
# <option class="page-nav__select-option" data-itemid="409" value="/newcastle-united">Newcastle United</option>
# <option class="page-nav__select-option" data-itemid="290" value="/norwich-city">Norwich City</option>
# <option class="page-nav__select-option" data-itemid="392" value="/southampton">Southampton</option>
# <option class="page-nav__select-option" data-itemid="608" value="/tottenham-hotspur">Tottenham Hotspur</option>
# <option class="page-nav__select-option" data-itemid="508" value="/watford">Watford</option>
# <option class="page-nav__select-option" data-itemid="367" value="/west-ham-united">West Ham United</option>
# <option class="page-nav__select-option" data-itemid="206" value="/wolverhampton-wanderers">Wolverhampton</option>
# </optgroup>
# <optgroup label="Championship">
# <option class="page-nav__select-option" data-itemid="191" value="/barnsley">Barnsley</option>
# <option class="page-nav__select-option" data-itemid="247" value="/birmingham-city">Birmingham City</option>
# <option class="page-nav__select-option" data-itemid="262" value="/blackburn-rovers">Blackburn Rovers</option>
# <option class="page-nav__select-option" data-itemid="231" value="/blackpool">Blackpool</option>
# <option class="page-nav__select-option" data-itemid="333" value="/bournemouth">Bournemouth</option>
# <option class="page-nav__select-option" data-itemid="236" value="/bristol-city">Bristol City</option>
# <option class="page-nav__select-option" data-itemid="202" value="/cardiff-city">Cardiff City</option>
# <option class="page-nav__select-option" data-itemid="571" value="/coventry-city">Coventry City</option>
# <option class="page-nav__select-option" data-itemid="295" value="/derby-county">Derby County</option>
# <option class="page-nav__select-option" data-itemid="407" value="/fulham">Fulham</option>
# <option class="page-nav__select-option" data-itemid="422" value="/huddersfield-town">Huddersfield Town</option>
# <option class="page-nav__select-option" data-itemid="253" value="/hull-city">Hull City</option>
# <option class="page-nav__select-option" data-itemid="226" value="/luton-town">Luton Town</option>
# <option class="page-nav__select-option" data-itemid="389" value="/middlesbrough">Middlesbrough</option>
# <option class="page-nav__select-option" data-itemid="704" value="/millwall">Millwall</option>
# <option class="page-nav__select-option" data-itemid="522" value="/nottingham-forest">Nottingham Forest</option>
# <option class="page-nav__select-option" data-itemid="630" value="/peterborough-united">Peterborough United</option>
# <option class="page-nav__select-option" data-itemid="436" value="/preston-north-end">Preston North End</option>
# <option class="page-nav__select-option" data-itemid="411" value="/queens-park-rangers">Queens Park Rangers</option>
# <option class="page-nav__select-option" data-itemid="216" value="/reading">Reading</option>
# <option class="page-nav__select-option" data-itemid="444" value="/sheffield-united">Sheffield United</option>
# <option class="page-nav__select-option" data-itemid="384" value="/stoke-city">Stoke City</option>
# <option class="page-nav__select-option" data-itemid="375" value="/swansea-city">Swansea City</option>
# <option class="page-nav__select-option" data-itemid="275" value="/west-bromwich-albion">West Bromwich Albion</option>
# </optgroup>
# <optgroup label="League One">
# <option class="page-nav__select-option" data-itemid="579" value="/accrington-stanley">Accrington Stanley</option>
# <option class="page-nav__select-option" data-itemid="419" value="/afc-wimbledon">AFC Wimbledon</option>
# <option class="page-nav__select-option" data-itemid="555" value="/bolton-wanderers">Bolton Wanderers</option>
# <option class="page-nav__select-option" data-itemid="294" value="/burton-albion">Burton Albion</option>
# <option class="page-nav__select-option" data-itemid="442" value="/cambridge-united">Cambridge United</option>
# <option class="page-nav__select-option" data-itemid="154" value="/charlton-athletic">Charlton Athletic</option>
# <option class="page-nav__select-option" data-itemid="534" value="/cheltenham-town">Cheltenham Town</option>
# <option class="page-nav__select-option" data-itemid="503" value="/crewe-alexandra">Crewe Alexandra</option>
# <option class="page-nav__select-option" data-itemid="397" value="/doncaster-rovers">Doncaster</option>
# <option class="page-nav__select-option" data-itemid="230" value="/fleetwood-town">Fleetwood Town</option>
# <option class="page-nav__select-option" data-itemid="356" value="/gillingham">Gillingham</option>
# <option class="page-nav__select-option" data-itemid="157" value="/ipswich-town">Ipswich Town</option>
# <option class="page-nav__select-option" data-itemid="181" value="/lincolncity">Lincoln City</option>
# <option class="page-nav__select-option" data-itemid="423" value="/milton-keynes-dons">Milton Keynes Dons</option>
# <option class="page-nav__select-option" data-itemid="273" value="/morecambe">Morecambe</option>
# <option class="page-nav__select-option" data-itemid="638" value="/oxford-united">Oxford United</option>
# <option class="page-nav__select-option" data-itemid="258" value="/plymouth-argyle">Plymouth Argyle</option>
# <option class="page-nav__select-option" data-itemid="298" value="/portsmouth">Portsmouth</option>
# <option class="page-nav__select-option" data-itemid="441" value="/rotherham-united">Rotherham United</option>
# <option class="page-nav__select-option" data-itemid="376" value="/sheffield-wednesday">Sheffield Wednesday</option>
# <option class="page-nav__select-option" data-itemid="773" value="/shrewsbury-town">Shrewsbury Town</option>
# <option class="page-nav__select-option" data-itemid="415" value="/sunderland">Sunderland</option>
# <option class="page-nav__select-option" data-itemid="457" value="/wigan-athletic">Wigan Athletic</option>
# <option class="page-nav__select-option" data-itemid="421" value="/wycombe-wanderers">Wycombe Wanderers</option>
# </optgroup>
# <optgroup label="League Two">
# <option class="page-nav__select-option" data-itemid="272" value="/barrow">Barrow</option>
# <option class="page-nav__select-option" data-itemid="448" value="/bradford-city">Bradford City</option>
# <option class="page-nav__select-option" data-itemid="282" value="/bristol-rovers">Bristol Rovers</option>
# <option class="page-nav__select-option" data-itemid="179" value="/carlisle-united">Carlisle United</option>
# <option class="page-nav__select-option" data-itemid="293" value="/colchester-united">Colchester United</option>
# <option class="page-nav__select-option" data-itemid="261" value="/crawley-town">Crawley Town</option>
# <option class="page-nav__select-option" data-itemid="185" value="/exeter-city">Exeter City</option>
# ...
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="http://www.sportinglife.com/" target="_blank">Sportinglife.com</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="http://www.teamtalk.com/" target="_blank">TEAMtalk.com</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="http://www.football365.com/" target="_blank">Football365.com</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="site-footer__col accordian__item" id="site-footer-partners-group&gt;">
# <a aria-controls="site-footer-partners" class="site-footer__head accordian__item-head" href="#" id="site-footer-partners">Partners</a>
# <div aria-labelledby="site-footer-partners" class="accordian__item-content-frame" id="site-footer-partners-nav">
# <ul class="site-footer__nav site-footer__nav--vertical accordian__item-content">
# <li class="site-footer__item">
# <a class="site-footer__link" href="https://www.skybet.com?aff=9749&amp;dcmp=ss_main_footer" target="_blank">Sky Bet</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="https://fantasyfootball.skysports.com/" target="_blank">Fantasy Football</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="https://super6.skysports.com" target="_blank">Super 6</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="http://www.planetrugby.com/" target="_blank">Planet Rugby</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="http://www.golf365.com" target="_blank">Golf365</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="http://www.planetf1.com" target="_blank">Planet F1</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="http://www.cricket365.com/" target="_blank">Cricket365</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="site-footer__col accordian__item" id="site-footer-channels-group&gt;">
# <a aria-controls="site-footer-channels" class="site-footer__head accordian__item-head" href="#" id="site-footer-channels">Sky Sports Channels</a>
# <div aria-labelledby="site-footer-channels" class="accordian__item-content-frame" id="site-footer-channels-nav">
# <ul class="site-footer__nav site-footer__nav--vertical accordian__item-content">
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-main-event">Sky Sports Main Event</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-premier-league">Sky Sports Premier League</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-football">Sky Sports Football</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-cricket">Sky Sports Cricket</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-golf">Sky Sports Golf</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-racing">Sky Sports Racing</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-f1">Sky Sports F1 </a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-action">Sky Sports Action</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-arena">Sky Sports Arena </a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-news">Sky Sports News</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/watch/sky-sports-mix">Sky Sports Mix</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="site-footer__col accordian__item" id="site-footer-sky-sites-group&gt;">
# <a aria-controls="site-footer-sky-sites" class="site-footer__head accordian__item-head" href="#" id="site-footer-sky-sites">More Sky Sites</a>
# <div aria-labelledby="site-footer-sky-sites" class="accordian__item-content-frame" id="site-footer-sky-sites-nav">
# <ul class="site-footer__nav site-footer__nav--vertical accordian__item-content">
# <li class="site-footer__item">
# <a class="site-footer__link" href="https://www.sky.com/" target="_blank">Sky.com</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="http://news.sky.com/" target="_blank">Sky News</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="https://www.skygroup.sky" target="_blank">Sky Group</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="https://business.sky.com/" target="_blank">Sky For Businesses</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="/workatskysports">Work @ Sky Sports</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="http://www.nowtv.com/promo/sky-sports?dcmp=ilc_SSNTV_skysports_hardcode_footer" target="_blank">NOW TV</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="https://communaltv.sky.com/" target="_blank">Sky Communal TV</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="https://www.skygroup.sky/corporate/bigger-picture" target="_blank">Bigger Picture</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="http://www.sky.com/shop/store-locator/" target="_blank">Store Locator</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="https://www.skymedia.co.uk/?utm_source=Sky_Sports&amp;utm_medium=Web_page&amp;utm_content=Sky_Sports_web_page&amp;utm_campaign=Sky_Sports_web_page" target="_blank">Advertise With Us</a>
# </li>
# <li class="site-footer__item">
# <a class="site-footer__link" href="https://accessories.sky.com/" target="_blank">Sky TV Accessories</a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# <!-- / LINKS GRID -->
# <ul class="site-footer__nav site-footer__nav--horizontal-nav">
# <li class="site-footer__item site-footer__item--inline">
# <a class="site-footer__link" href="https://www.sky.com/help/articles/skycom-terms-and-conditions" target="_blank">Terms &amp; Conditions</a>
# </li>
# <li class="site-footer__item site-footer__item--inline">
# <a class="site-footer__link" href="https://www.sky.com/help/articles/sky-privacy-and-cookies-notice" target="_blank">Privacy &amp; Cookies Notice</a>
# </li>
# <li class="site-footer__item site-footer__item--inline">
# <a class="site-footer__link" href="#privacy-options">Privacy Options</a>
# </li>
# <li class="site-footer__item site-footer__item--inline">
# <a class="site-footer__link" href="https://www.skyaccessibility.sky/" target="_blank">Accessibility Information</a>
# </li>
# <li class="site-footer__item site-footer__item--inline">
# <a class="site-footer__link" href="/contact-us">Contact Us</a>
# </li>
# </ul>
# <p class="site-footer__copyright">
# <a class="svg-logo site-footer__site-logo" href="https://www.skysports.com">
# <img class="svg-logo__image" onerror="this.onerror=null;this.src='https://e1.365dm.com/tvlogos/channels/Sky-Sports-Logo.png'" src="https://e1.365dm.com/tvlogos/channels/Sky-Sports-Logo.svg"/>
# </a>
#       ©2021 Sky UK
#     </p>
# </div>
# </div>
# <div class="callfn" data-campaign-id="2370" data-component-name="sdc-site-consent-management" data-fn="sdc-site-consent-management" data-lite="true" data-privacy-manager-id="157602" data-selector=".site-footer a[href='#privacy-options']" data-spv2="true"></div>
# <!-- / SITE FOOTER -->
# <link href="/common/styles/project-base-vars.css" rel="stylesheet" type="text/css"/>
# <script src="/static/require-2.1.0-15f03d8ff7a4b.js"></script>
# <script src="/static/include-d91f363fba565d07b7eb760f9c9acd1e-b5a64659e3025.js"></script>
# <script>
#
#         require.config({"shim":{"facebook-sdk":{"exports":"FB"}},"baseUrl":"/","paths":{"skysports_com":"static/skysports_com-e94d57842da5d","skysports_digrev":"static/skysports_digrev-bcefc920652e7","skysports_legacy":"static/skysports_legacy-8472f78da6ff1","skysports_ipad_components":"static/skysports_ipad_components-9347556046b82","skysports_sap":"core/js/../static/js/skysports_sap","requireLib":"static/require-2.1.0-15f03d8ff7a4b","class":"static/class-55bbf080a62c3","countdown":"static/countdown-3c7569426f127","energize":"static/energize-bac53226fb-9795bcfacb255","hammer":"static/hammer-a592776ebb-f14662ea8bb34","marker-clusterer":"static/marker-clusterer-8a934d664ede6","moment":"static/moment-1.7.2-33075cfd4ad32","reqwest":"static/reqwest-a845dfd832-dea6ebed2de7d","scroll-pane":"static/ftscroller-280c6900bc-ca9da74da3fb9","underscore":"static/lodash.custom-80970c5a1825d","adaptive-content":"static/adaptive-content-1fc383fae518a","article-widget-betting":"static/article-widget-betting-7a9641160b027","app-bridge":"static/app-bridge-30b975666386a","article-advert":"static/article-advert-fa40febcc7b0f","article-outbrain":"static/article-outbrain-bba64c5034e96","autocomplete":"static/autocomplete-62886d6993248","autocomplete-lite":"static/autocomplete-lite-c397d58384aeb","accordian":"static/accordian-87ec71ccbfdd1","betting-lines":"static/betting-lines-31e5cdbecf2bc","bskyb-omniture":"static/bskyb-omniture-de3e9caef9fce","bskyb-omniture-1-2":"static/bskyb-omniture-1.2-ef8627d226d42","calendar-url-builder":"static/calendar-url-builder-863fca999d8c8","carousel":"static/carousel-cfdab6400e999","carousel-lite":"static/carousel-lite-520eccc372b67","close-me":"static/close-me-1dd5bf41462eb","content-stream":"static/content-stream-4ceef3bbd096b","content-swap":"static/content-swap-bdbe29a70d8f9","countdown-widget":"static/countdown-widget-459a93f477481","comments-reply":"static/comments-reply-81d5853bdd03b","cookie":"static/cookie-072824b3a5047","android-notice":"static/android-notice-58d95f174579a","create-audio":"static/create-audio-f77436036a203","create-video":"static/create-video-f5fe547b889be","create-video2":"static/create-video2-bb132ac918d30","dataset":"static/dataset-487d6875fe94d","datepicker":"static/datepicker-b112a28bd151b","datepicker2":"static/datepicker2-d10188465db39","dom":"static/dom-f554c2354ab77","dropdown":"static/dropdown-de4729ed67884","dropdown-select":"static/dropdown-select-bbaa962ff8888","edigital-survey":"static/edigital-survey-6.0.6.0-13762d4026255","element-listener":"static/element-listener-39391d1341a3c","environment":"static/environment-d24a016d1c736","events":"static/events-e6bde13ac56dc","facebook-sdk":"//connect.facebook.net/en_US/all","form":"static/form-269f9f014d35a","form-chart":"static/form-chart-8e3b2b92c7e77","form-validation":"static/form-validation-76d631ee9c0fb","html-poller":"static/html-poller-db12e18d06d04","implicit-personalisation-display":"static/implicit-personalisation-display-2bc93246729e4","implicit-personalisation-storage":"static/implicit-personalisation-storage-a4eb341b47077","implicit-personalisation-removal":"static/implicit-personalisation-removal-7556598e29ff5","inverted-listener":"static/inverted-listener-07a7ace73331d","iscroll-lite":"static/iscroll-lite-03ad473f62d1a","keyboard-listener":"static/keyboard-listener-f6b30a391df5b","keyboard-view":"static/keyboard-view-5a68be0e6dc00","lazy-images":"static/lazy-images-f5238f2864a52","live-article":"static/live-article-95ba706f060b3","live-cricket":"static/live-cricket-98d8debeb2633","live-sport":"static/live-sport-77265bd8792ec","live-update":"static/live-update-945d95543ad61","live-refresh":"static/live-refresh-5ebefb5206c82","live-refresh-darts-table-controller":"static/live-refresh-darts-table-controller-d6c7bb8af0efe","live-refresh-darts-table-view":"static/live-refresh-darts-table-view-5c4f5e87a3cb2","live-refresh-football-controller":"static/live-refresh-football-controller-461aca93a03fe","live-refresh-football-vie ...
#
#         require(['skysports_digrev', 'sdc-site-pub-sub'], function (appController, pubsub) {
#             window.sdc = window.sdc || {};
#             pubsub.init(window.sdc);
#
#             appController.init();
#         });
#
#     </script>
# <script type="text/javascript">//<![CDATA[
#     _uzactions = window._uzactions || [];
#     _uzactions.push(['_setID', 'A8C553219B93EA11AA5EC9768AD49726']);
#     _uzactions.push(['_setSID', 'BCECC91A9B93EA11AA5EC9768AD49726']);
#     _uzactions.push(['_start']);
#     (function() {
#         var uz = document.createElement('script'); uz.type = 'text/javascript'; uz.async = true; uz.charset = 'utf-8';
#         uz.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdn4.userzoom.com/trueintent/js/uz_til.js?cuid=B586ADA60ECEE411B0190022196C2B88';
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(uz, s);
#     })();
#     //]]></script> <script src="/static/require-2.1.0-15f03d8ff7a4b.js" type="text/javascript"></script>
# <script>
# SKY_SPORTS.deferred(function () {
#
#     var st_tag = document.createElement('script');
#     st_tag.async = true;
#     st_tag.src = "//native.sharethrough.com/assets/tag.js";
#     document.getElementsByTagName('head')[0].appendChild(st_tag);
#
# });
# </script>
# <script async="" src="https://cloud-static.storage.googleapis.com/production/widgets/mk2/js/common/generator.min.js"></script><script type="text/javascript">window.ocEnv={url:window.location.href,};</script><script>
#     SKY_SPORTS.deferred(function(){
#         require(['bskyb-omniture'], function (bskybOmniture) {
#
#             var aamGetCookie =  function (c_name)
#             {
#                 var i, x, y, c = document.cookie.split(";");
#                 for (i = 0; i < c.length; i++)
#                 {
#                     x = c[i].substr(0, c[i].indexOf("="));
#                     y = c[i].substr(c[i].indexOf("=") + 1);
#                     x = x.replace(/^\s+|\s+$/g, "");
#                     if (x == c_name)
#                     {
#                         return unescape(y);
#                     }
#                 }
#             };
#
#             var tracking = '';
#             var cookie = aamGetCookie("interactive");
#             var interactive = (cookie) ? JSON.parse(cookie) : {};
#             if( 'undefined' !== typeof interactive.tid ) {
#                 tracking = interactive.tid;
#             }
#
#             var omnitureInitiated = false;
#
#             var initAnalytics = function(targetData) {
#
#                 if(omnitureInitiated) {
#                     return;
#                 }
#
#                 omnitureInitiated = true;
#
#                 var omnitureData = {
#                     trackingId: tracking,
#                     site: "sky/portal/sports",
#                     section: "football/barclays_premier_league",
#                     contentType: "table",
#                                         contentId: "",
#                     sport: "Football",                    account: "bskybsports"
#                 };
#
#
#                 if(typeof targetData !== "undefined" && targetData.tntVal) {
#                     omnitureData.tnt = targetData.tntVal;
#                 }
#
#                 // site-wide analytics
#                 bskybOmniture.init(omnitureData);
#             };
#
#             if(window.sdc && window.sdc.pubSub) {
#                 window.sdc.pubSub.subscribe('dynamic-tile.events.adobe-target-fetched', function(data) {
#                     initAnalytics(data);
#                 });
#             }
#
#             setTimeout(initAnalytics, 2000);
#
#         });
#     });
#
#     var s_account = "bskybsports";
# </script>
# <script type="text/javascript">_satellite.pageBottom();</script>
# <script>
#       var _sf_async_config = _sf_async_config || {};
#       _sf_async_config.sections = 'type:table,premier league,football';
#
#
#     window._sf_endpt = new Date().getTime();
#     var script = document.createElement('script');
#     script.src = document.location.protocol + '//static.chartbeat.com/js/chartbeat.js';
#     document.body.appendChild(script);
#   </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam-cell.nr-data.net","licenseKey":"517f0b291f","applicationID":"545304393","transactionName":"blcEMUpZCxdYV0MIXVcdJRBLTAoJFlJYDkZbUwoJF1sKCk1GWA1eXEAVSntXCBRcQF4VW1ZcFSZXVhEWVlhbBEAXQg4V","queueTime":0,"applicationTime":347,"atts":"QhATRwJDGEgbVRVbSURP","errorBeacon":"bam-cell.nr-data.net","agent":""}</script></body>
# </html>
# >

# %%
print(soup.find('a'))
# Out:
# <a class="svg-logo site-header__logo" href="https://www.skysports.com">
# <img class="svg-logo__image" onerror="this.onerror=null;this.src='/core/img/channels/Sky-Sports-Logo.png'" src="/core/img/channels/Sky-Sports-Logo-transparent.svg"/>
# </a>

# %%
print(soup.find_all('a'))
# Out:
# [<a class="svg-logo site-header__logo" href="https://www.skysports.com">
# <img class="svg-logo__image" onerror="this.onerror=null;this.src='/core/img/channels/Sky-Sports-Logo.png'" src="/core/img/channels/Sky-Sports-Logo-transparent.svg"/>
# </a>, <a class="site-header__col site-header__col4 site-header__nav-button-hit-area" data-role="open-left-hand-nav" href="#no-js-nav" tabindex="1">
# <svg class="site-header__nav-button" version="1.1" viewbox="0 0 2048 2048" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <rect height="256" width="2048" y="384"></rect>
# <rect height="256" width="2048" y="896"></rect>
# <rect height="256" width="2048" y="1408"></rect>
# </svg>
# </a>, <a class="page-header__breadcrumb-link" href="https://www.skysports.com/football">Football</a>, <a class="page-header__title-link" href="/premier-league">
# <abbr class="swap-text--bp30" title="Premier League">
# <span class="swap-text__target">Premier League</span>
# </abbr>
# </a>, <a aria-controls="page-nav-control" class="page-nav__head" href="#page-nav" id="page-nav-control">
# <h3 class="page-nav__title">Table</h3>
# <div class="page-nav__title-more"></div>
# </a>, <a class="page-nav__link" href="/premier-league-news">News</a>, <a class="page-nav__select-mask page-nav__link" href="/football/teams">Teams</a>, <a class="page-nav__link" href="/premier-league-fixtures">Fixtures</a>, <a class="page-nav__link" href="/premier-league-results">Results</a>, <a class="page-nav__link page-nav__link--active" href="/premier-league-table">Table</a>, <a class="page-nav__link" href="/football/team-transfers-premier-league">Transfers</a>, <a class="page-nav__link" href="/watch/video/sports/football/competitions/premier-league">Video</a>, <a class="page-nav__link" href="/football/pundits">Pundits</a>, <a class="page-nav__link" href="/watch/football-on-sky/competitions/premier-league">On Sky</a>, <a class="page-nav__link" href="http://live.skysports.com/ScoreCentre/live.html" target="_blank">Scores</a>, <a class="page-nav__link" href="https://m.skybet.com/football?aff=9757&amp;dcmp=ss_sub_nav_FB" target="_blank">Bet</a>, <a class="page-nav__link" href="https://www.skysports.com/football">Football Home</a>, <a class="page-filters__button" href="#page-filters__body">All tables</a>, <a class="page-filters__filter-link" href="/premier-league-table/2021">2021/22</a>, <a class="page-filters__filter-link" href="/premier-league-table/2020">2020/21</a>, <a class="page-filters__filter-link" href="/premier-league-table/2019">2019/20</a>, <a class="page-filters__filter-link" href="/premier-league-table/2018">2018/19</a>, <a class="page-filters__filter-link" href="/premier-league-table/2017">2017/18</a>, <a class="page-filters__filter-link" href="/premier-league-table/2016">2016/17</a>, <a class="page-filters__filter-link" href="/premier-league-table/2015">2015/16</a>, <a class="page-filters__filter-link" href="/premier-league-table/2014">2014/15</a>, <a class="page-filters__filter-link" href="/premier-league-table/2013">2013/14</a>, <a class="page-filters__filter-link" href="/premier-league-table/2012">2012/13</a>, <a class="page-filters__filter-link page-filters__filter-link--active" href="/premier-league-table/2011">2011/12</a>, <a class="page-filters__filter-link" href="/premier-league-table/2010">2010/11</a>, <a class="page-filters__filter-link page-filters__filter-link--active" href="/premier-league-table">
# <span class="swap-text--bp30" title="Premier League">
# <span class="swap-text__target">Premier League</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/champions-league-table">
# <span class="swap-text--bp30" title="Champions League">
# <span class="swap-text__target">Champions League</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/uefa-nations-league-table">
# <span class="swap-text--bp30" title="Nations League">
# <span class="swap-text__target">UEFA Nations League</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/championship-table">
# <span class="swap-text--bp30" title="Sky Bet Ch'ship">
# <span class="swap-text__target">Championship</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/league-1-table">
# <span class="swap-text--bp30" title="Sky Bet League One">
# <span class="swap-text__target">League One</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/euro-2020-table">
# <span class="swap-text--bp30" title="European Championships">
# <span class="swap-text__target">European Championships</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/league-2-table">
# <span class="swap-text--bp30" title="Sky Bet League Two">
# <span class="swap-text__target">League Two</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/scottish-premier-table">
# <span class="swap-text--bp30" title="Scots Prem">
# <span class="swap-text__target">Scottish Premiership</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/scottish-championship-table">
# <span class="swap-text--bp30" title="Scots Champ">
# <span class="swap-text__target">Scottish Championship</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/scottish-league-one-table">
# <span class="swap-text--bp30" title="Scottish League 1">
# <span class="swap-text__target">Scottish League One</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/scottish-league-two-table">
# <span class="swap-text--bp30" title="Scottish League 2">
# <span class="swap-text__target">Scottish League Two</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/scottish-league-cup-table">
# <span class="swap-text--bp30" title="Scot League Cup">
# <span class="swap-text__target">Scottish League Cup</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/under-21s-table">
# <span class="swap-text--bp30" title="European U-21 Champ">
# <span class="swap-text__target">European U-21 Champ</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/europa-league-table">
# <span class="swap-text--bp30" title="Europa League">
# <span class="swap-text__target">Europa League</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/efl-trophy-table">
# <span class="swap-text--bp30" title="Papa John's Trophy">
# <span class="swap-text__target">Papa John's Trophy</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/copa-america-table">
# <span class="swap-text--bp30" title="Copa America">
# <span class="swap-text__target">Copa America</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/la-liga-table">
# <span class="swap-text--bp30" title="Spanish La Liga">
# <span class="swap-text__target">La Liga</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/she-believes-cup-table">
# <span class="swap-text--bp30" title="SheBelieves Cup">
# <span class="swap-text__target">SheBelieves Cup</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/serie-a-table">
# <span class="swap-text--bp30" title="Italian Serie A">
# <span class="swap-text__target">Serie A</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/bundesliga-table">
# <span class="swap-text--bp30" title="German Bundesliga">
# <span class="swap-text__target">Bundesliga</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/eredivisie-table">
# <span class="swap-text--bp30" title="Dutch Eredivisie">
# <span class="swap-text__target">Eredivisie</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/ligue-1-table">
# <span class="swap-text--bp30" title="French Ligue 1">
# <span class="swap-text__target">Ligue 1</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/womens-super-league-table">
# <span class="swap-text--bp30" title="FA WSL">
# <span class="swap-text__target">FA Women's Super League</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/mls-table">
# <span class="swap-text--bp30" title="MLS">
# <span class="swap-text__target">American MLS League</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/womens-premier-league-southern-division-table">
# <span class="swap-text--bp30" title="FA Women's Nat Lge - South">
# <span class="swap-text__target">FA Women's Nat Lge - South</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/womens-premier-league-northern-division-table">
# <span class="swap-text--bp30" title="FA Women's Nat Lge - North">
# <span class="swap-text__target">FA Women's Nat Lge - North</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/womens-super-league-2-table">
# <span class="swap-text--bp30" title="FA Women's Championship">
# <span class="swap-text__target">FA Women's Championship</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/chinese-super-league-table">
# <span class="swap-text--bp30" title="Chinese Super League">
# <span class="swap-text__target">Chinese Super League</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/football/competitions/vanarama-national-league/table">
# <span class="swap-text--bp30" title="National League">
# <span class="swap-text__target">National League</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/football/competitions/vanarama-national-league-north/table">
# <span class="swap-text--bp30" title="National League North">
# <span class="swap-text__target">National League North</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/football/competitions/vanarama-national-league-south/table">
# <span class="swap-text--bp30" title="National League South">
# <span class="swap-text__target">National League South</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/football/competitions/world-cup-qualifiers/table">
# <span class="swap-text--bp30" title="World Cup Qualifiers">
# <span class="swap-text__target">World Cup Qualifiers</span>
# </span>
# </a>, <a class="page-filters__filter-link" href="/football/competitions/womens-world-cup-qualifiers/table">
# <span class="swap-text--bp30" title="Women's WC Qualifiers">
# <span class="swap-text__target">Women's WC Qualifiers</span>
# </span>
# </a>, <a class="standing-table__cell--name-link" href="/manchester-city">Manchester City</a>, <a class="standing-table__cell--name-link" href="/manchester-united">Manchester United</a>, <a class="standing-table__cell--name-link" href="/arsenal">Arsenal</a>, <a class="standing-table__cell--name-link" href="/tottenham-hotspur">Tottenham Hotspur</a>, <a class="standing-table__cell--name-link" href="/newcastle-united">Newcastle United</a>, <a class="standing-table__cell--name-link" href="/chelsea">Chelsea</a>, <a class="standing-table__cell--name-link" href="/everton">Everton</a>, <a class="standing-table__cell--name-link" href="/liverpool">Liverpool</a>, <a class="standing-table__cell--name-link" href="/fulham">Fulham</a>, <a class="standing-table__cell--name-link" href="/west-bromwich-albion">West Bromwich Albion</a>, <a class="standing-table__cell--name-link" href="/swansea-city">Swansea City</a>, <a class="standing-table__cell--name-link" href="/norwich-city">Norwich City</a>, <a class="standing-table__cell--name-link" href="/sunderland">Sunderland</a>, <a class="standing-table__cell--name-link" href="/stoke-city">Stoke City</a>, <a class="standing-table__cell--name-link" href="/wigan-athletic">Wigan Athletic</a>, <a class="standing-table__cell--name-link" href="/aston-villa">Aston Villa</a>, <a class="standing-table__cell--name-link" href="/queens-park-rangers">Queens Park Rangers</a>, <a class="standing-table__cell--name-link" href="/bolton-wanderers">Bolton Wanderers</a>, <a class="standing-table__cell--name-link" href="/blackburn-rovers">Blackburn Rovers</a>, <a class="standing-table__cell--name-link" href="/wolverhampton-wanderers">Wolverhampton Wanderers</a>, <a class="accordian__item-head site-nav-mobile__link" href="/" tabindex="100">
#                         Home                    </a>, <a aria-controls="site-nav-desktop-sports-more-nav" class="accordian__item-head site-nav-mobile__link site-nav-mobile__link-more" href="#site-nav-desktop-sports-more-nav" id="site-nav-desktop-sports-more">
#                     Sports                </a>, <a class="site-nav-mobile__sub-link" href="/football" tabindex="100">
#                                 Football                            </a>, <a class="site-nav-mobile__sub-link" href="/f1" tabindex="100">
#                                 F1                            </a>, <a class="site-nav-mobile__sub-link" href="/cricket" tabindex="100">
#                                 Cricket                            </a>, <a class="site-nav-mobile__sub-link" href="/rugby-union" tabindex="100">
#                                 Rugby Union                            </a>, <a class="site-nav-mobile__sub-link" href="/rugby-league" tabindex="100">
#                                 Rugby League                            </a>, <a class="site-nav-mobile__sub-link" href="/golf" tabindex="100">
#                                 Golf                            </a>, <a class="site-nav-mobile__sub-link" href="/boxing" tabindex="100">
#                                 Boxing                            </a>, <a class="site-nav-mobile__sub-link" href="/nfl" tabindex="100">
#                                 NFL                            </a>, <a class="site-nav-mobile__sub-link" href="/olympics" tabindex="100">
#                                 Olympics                            </a>, <a class="site-nav-mobile__sub-link" href="/tennis" tabindex="100">
#                                 Tennis                            </a>, <a class="site-nav-mobile__sub-link" href="/racing" tabindex="100">
#                                 Racing                            </a>, <a class="site-nav-mobile__sub-link" href="/darts" tabindex="100">
#                                 Darts                            </a>, <a class="site-nav-mobile__sub-link" href="/nba" tabindex="100">
#                                 NBA                            </a>, <a class="site-nav-mobile__sub-link" href="/netball" tabindex="100">
#                                 Netball                            </a>, <a class="site-nav-mobile__sub-link" href="/gaa" tabindex="100">
#                                 GAA                            </a>, <a class="site-nav-mobile__sub-link" href="/mma" tabindex="100">
#                                 MMA                            </a>, <a class="site-nav-mobile__sub-link" href="/more-sports" tabindex="100">
#                                 More Sports                            </a>, <a class="accordian__item-head site-nav-mobile__link" href="/live-scores" tabindex="100">
#                         Scores                    </a>, <a class="accordian__item-head site-nav-mobile__link" href="/watch/video" tabindex="100">
#                         Video                    </a>, <a class="accordian__item-head site-nav-mobile__link" href="/watch" tabindex="100">
#                         TV                    </a>, <a class="accordian__item-head site-nav-mobile__link" href="https://www.skybet.com?aff=9749&amp;dcmp=ss_main_nav" tabindex="100" target="_blank">
#                         Sky Bet                    </a>, <a class="accordian__item-head site-nav-mobile__link" href="/games" tabindex="100">
#                         Games                    </a>, <a aria-controls="site-nav-desktop-more-more-nav" class="accordian__item-head site-nav-mobile__link site-nav-mobile__link-more" href="#site-nav-desktop-more-more-nav" id="site-nav-desktop-more-more">
#                     More                </a>, <a class="site-nav-mobile__sub-link" href="/transfer-centre" tabindex="100">
#                                 Transfer Centre                            </a>, <a class="site-nav-mobile__sub-link" href="/watch/sport-on-sky" tabindex="100">
#                                 Live on Sky                            </a>, <a class="site-nav-mobile__sub-link" href="/get-sky?dcmp=gss_more_dropdown" tabindex="100">
#                                 Get Sky Sports                            </a>, <a class="site-nav-mobile__sub-link" href="/watch/tv-shows" tabindex="100">
#                                 TV Shows                            </a>, <a class="site-nav-mobile__sub-link" href="/watch/tv-guide" tabindex="100">
#                                 TV Guide                            </a>, <a class="site-nav-mobile__sub-link" href="https://www.sky.com/shop/tv/sky-go/?dcmp=skygo_ss.com_more" tabindex="100" target="_blank">
#                                 Sky Go                            </a>, <a class="site-nav-mobile__sub-link" href="http://www.nowtv.com/promo/sky-sports?dcmp=ilc_SSNTV_skysports_hardcode_moredropdownlink" tabindex="100" target="_blank">
#                                 Now TV                            </a>, <a class="site-nav-mobile__sub-link" href="https://www.kickitout.org/forms/online-reporting-form" tabindex="100" target="_blank">
#                                 Kick It Out                            </a>, <a class="site-nav-mobile__sub-link" href="/football/news/topic/8724/black-lives-matter" tabindex="100">
#                                 Black Lives Matter                            </a>, <a class="site-nav-mobile__sub-link" href="/podcasts" tabindex="100">
#                                 Podcasts                            </a>, <a class="site-nav-mobile__sub-link" href="/mobile" tabindex="100">
#                                 Mobile                            </a>, <a class="site-nav-mobile__sub-link" href="https://twitter.com/SkySports" tabindex="100" target="_blank">
#                                 Twitter                            </a>, <a class="site-nav-mobile__sub-link" href="https://www.facebook.com/SkySports" tabindex="100" target="_blank">
#                                 Facebook                            </a>, <a class="site-nav-mobile__sub-link" href="/contact-us" tabindex="100">
#                                 Contact Us                            </a>, <a class="site-nav-mobile__sub-link" href="/workatskysports" tabindex="100">
#                                 Work @ Sky Sports                            </a>, <a class="site-nav-mobile__sub-link" href="https://www.sky.com/help/articles/skycom-terms-and-conditions" tabindex="100" target="_blank">
#                                 Terms &amp; Conditions                            </a>, <a class="social-nav__link social-nav__link--twitter icon" data-icon="" href="https://twitter.com/SkySports" target="_blank">Twitter</a>, <a class="social-nav__link social-nav__link--facebook icon" data-icon="" href="https://www.facebook.com/SkySports" target="_blank">Facebook</a>, <a aria-controls="site-footer-sky-sports-more" class="site-footer__head accordian__item-head" href="#" id="site-footer-sky-sports-more">Sky Sports</a>, <a class="site-footer__link" href="/watch/get-sky">Get Sky Sports</a>, <a class="site-footer__link" href="/mobile">Sky Sports Apps</a>, <a class="site-footer__link" href="http://www.sportinglife.com/" target="_blank">Sportinglife.com</a>, <a class="site-footer__link" href="http://www.teamtalk.com/" target="_blank">TEAMtalk.com</a>, <a class="site-footer__link" href="http://www.football365.com/" target="_blank">Football365.com</a>, <a aria-controls="site-footer-partners" class="site-footer__head accordian__item-head" href="#" id="site-footer-partners">Partners</a>, <a class="site-footer__link" href="https://www.skybet.com?aff=9749&amp;dcmp=ss_main_footer" target="_blank">Sky Bet</a>, <a class="site-footer__link" href="https://fantasyfootball.skysports.com/" target="_blank">Fantasy Football</a>, <a class="site-footer__link" href="https://super6.skysports.com" target="_blank">Super 6</a>, <a class="site-footer__link" href="http://www.planetrugby.com/" target="_blank">Planet Rugby</a>, <a class="site-footer__link" href="http://www.golf365.com" target="_blank">Golf365</a>, <a class="site-footer__link" href="http://www.planetf1.com" target="_blank">Planet F1</a>, <a class="site-footer__link" href="http://www.cricket365.com/" target="_blank">Cricket365</a>, <a aria-controls="site-footer-channels" class="site-footer__head accordian__item-head" href="#" id="site-footer-channels">Sky Sports Channels</a>, <a class="site-footer__link" href="/watch/sky-sports-main-event">Sky Sports Main Event</a>, <a class="site-footer__link" href="/watch/sky-sports-premier-league">Sky Sports Premier League</a>, <a class="site-footer__link" href="/watch/sky-sports-football">Sky Sports Football</a>, <a class="site-footer__link" href="/watch/sky-sports-cricket">Sky Sports Cricket</a>, <a class="site-footer__link" href="/watch/sky-sports-golf">Sky Sports Golf</a>, <a class="site-footer__link" href="/watch/sky-sports-racing">Sky Sports Racing</a>, <a class="site-footer__link" href="/watch/sky-sports-f1">Sky Sports F1 </a>, <a class="site-footer__link" href="/watch/sky-sports-action">Sky Sports Action</a>, <a class="site-footer__link" href="/watch/sky-sports-arena">Sky Sports Arena </a>, <a class="site-footer__link" href="/watch/sky-sports-news">Sky Sports News</a>, <a class="site-footer__link" href="/watch/sky-sports-mix">Sky Sports Mix</a>, <a aria-controls="site-footer-sky-sites" class="site-footer__head accordian__item-head" href="#" id="site-footer-sky-sites">More Sky Sites</a>, <a class="site-footer__link" href="https://www.sky.com/" target="_blank">Sky.com</a>, <a class="site-footer__link" href="http://news.sky.com/" target="_blank">Sky News</a>, <a class="site-footer__link" href="https://www.skygroup.sky" target="_blank">Sky Group</a>, <a class="site-footer__link" href="https://business.sky.com/" target="_blank">Sky For Businesses</a>, <a class="site-footer__link" href="/workatskysports">Work @ Sky Sports</a>, <a class="site-footer__link" href="http://www.nowtv.com/promo/sky-sports?dcmp=ilc_SSNTV_skysports_hardcode_footer" target="_blank">NOW TV</a>, <a class="site-footer__link" href="https://communaltv.sky.com/" target="_blank">Sky Communal TV</a>, <a class="site-footer__link" href="https://www.skygroup.sky/corporate/bigger-picture" target="_blank">Bigger Picture</a>, <a class="site-footer__link" href="http://www.sky.com/shop/store-locator/" target="_blank">Store Locator</a>, <a class="site-footer__link" href="https://www.skymedia.co.uk/ ...
# <img class="svg-logo__image" onerror="this.onerror=null;this.src='https://e1.365dm.com/tvlogos/channels/Sky-Sports-Logo.png'" src="https://e1.365dm.com/tvlogos/channels/Sky-Sports-Logo.svg"/>
# </a>]

# %%
soup.find_all('a')[1]
# Out:
# <a class="site-header__col site-header__col4 site-header__nav-button-hit-area" data-role="open-left-hand-nav" href="#no-js-nav" tabindex="1">
# <svg class="site-header__nav-button" version="1.1" viewbox="0 0 2048 2048" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <rect height="256" width="2048" y="384"></rect>
# <rect height="256" width="2048" y="896"></rect>
# <rect height="256" width="2048" y="1408"></rect>
# </svg>
# </a>

# %%
league= soup.find('table', class_='standing-table__table')

# %%
league_table = league.find_all('tbody')

# %%
print(league_table)
# Out:
# [<tbody>
# <tr class="standing-table__row" data-item-id="345">
# <td class="standing-table__cell">1</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Manchester City" data-short-name="Manchester City">
# <a class="standing-table__cell--name-link" href="/manchester-city">Manchester City</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">28</td>
# <td class="standing-table__cell is-hidden--bp35">5</td>
# <td class="standing-table__cell is-hidden--bp35">5</td>
# <td class="standing-table__cell is-hidden--bp35">93</td>
# <td class="standing-table__cell is-hidden--bp35">29</td>
# <td class="standing-table__cell">64</td>
# <td class="standing-table__cell" data-sort-value="1">89</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="210">
# <td class="standing-table__cell">2</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Manchester United" data-short-name="Manchester United">
# <a class="standing-table__cell--name-link" href="/manchester-united">Manchester United</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">28</td>
# <td class="standing-table__cell is-hidden--bp35">5</td>
# <td class="standing-table__cell is-hidden--bp35">5</td>
# <td class="standing-table__cell is-hidden--bp35">89</td>
# <td class="standing-table__cell is-hidden--bp35">33</td>
# <td class="standing-table__cell">56</td>
# <td class="standing-table__cell" data-sort-value="2">89</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="413">
# <td class="standing-table__cell">3</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Arsenal" data-short-name="Arsenal">
# <a class="standing-table__cell--name-link" href="/arsenal">Arsenal</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">21</td>
# <td class="standing-table__cell is-hidden--bp35">7</td>
# <td class="standing-table__cell is-hidden--bp35">10</td>
# <td class="standing-table__cell is-hidden--bp35">74</td>
# <td class="standing-table__cell is-hidden--bp35">49</td>
# <td class="standing-table__cell">25</td>
# <td class="standing-table__cell" data-sort-value="3">70</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="608">
# <td class="standing-table__cell">4</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Tottenham Hotspur" data-short-name="Tottenham Hotspur">
# <a class="standing-table__cell--name-link" href="/tottenham-hotspur">Tottenham Hotspur</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">20</td>
# <td class="standing-table__cell is-hidden--bp35">9</td>
# <td class="standing-table__cell is-hidden--bp35">9</td>
# <td class="standing-table__cell is-hidden--bp35">66</td>
# <td class="standing-table__cell is-hidden--bp35">41</td>
# <td class="standing-table__cell">25</td>
# <td class="standing-table__cell" data-sort-value="4">69</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row standing-table__row--divider" data-item-id="409">
# <td class="standing-table__cell">5</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Newcastle United" data-short-name="Newcastle United">
# <a class="standing-table__cell--name-link" href="/newcastle-united">Newcastle United</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">19</td>
# <td class="standing-table__cell is-hidden--bp35">8</td>
# <td class="standing-table__cell is-hidden--bp35">11</td>
# <td class="standing-table__cell is-hidden--bp35">56</td>
# <td class="standing-table__cell is-hidden--bp35">51</td>
# <td class="standing-table__cell">5</td>
# <td class="standing-table__cell" data-sort-value="5">65</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row standing-table__row--divider" data-item-id="524">
# <td class="standing-table__cell">6</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Chelsea" data-short-name="Chelsea">
# <a class="standing-table__cell--name-link" href="/chelsea">Chelsea</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">18</td>
# <td class="standing-table__cell is-hidden--bp35">10</td>
# <td class="standing-table__cell is-hidden--bp35">10</td>
# <td class="standing-table__cell is-hidden--bp35">65</td>
# <td class="standing-table__cell is-hidden--bp35">46</td>
# <td class="standing-table__cell">19</td>
# <td class="standing-table__cell" data-sort-value="6">64</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="229">
# <td class="standing-table__cell">7</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Everton" data-short-name="Everton">
# <a class="standing-table__cell--name-link" href="/everton">Everton</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">15</td>
# <td class="standing-table__cell is-hidden--bp35">11</td>
# <td class="standing-table__cell is-hidden--bp35">12</td>
# <td class="standing-table__cell is-hidden--bp35">50</td>
# <td class="standing-table__cell is-hidden--bp35">40</td>
# <td class="standing-table__cell">10</td>
# <td class="standing-table__cell" data-sort-value="7">56</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="155">
# <td class="standing-table__cell">8</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Liverpool" data-short-name="Liverpool">
# <a class="standing-table__cell--name-link" href="/liverpool">Liverpool</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">14</td>
# <td class="standing-table__cell is-hidden--bp35">10</td>
# <td class="standing-table__cell is-hidden--bp35">14</td>
# <td class="standing-table__cell is-hidden--bp35">47</td>
# <td class="standing-table__cell is-hidden--bp35">40</td>
# <td class="standing-table__cell">7</td>
# <td class="standing-table__cell" data-sort-value="8">52</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="407">
# <td class="standing-table__cell">9</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Fulham" data-short-name="Fulham">
# <a class="standing-table__cell--name-link" href="/fulham">Fulham</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">14</td>
# <td class="standing-table__cell is-hidden--bp35">10</td>
# <td class="standing-table__cell is-hidden--bp35">14</td>
# <td class="standing-table__cell is-hidden--bp35">48</td>
# <td class="standing-table__cell is-hidden--bp35">51</td>
# <td class="standing-table__cell">-3</td>
# <td class="standing-table__cell" data-sort-value="9">52</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="275">
# <td class="standing-table__cell">10</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="West Bromwich Albion" data-short-name="West Bromwich Albion">
# <a class="standing-table__cell--name-link" href="/west-bromwich-albion">West Bromwich Albion</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">13</td>
# <td class="standing-table__cell is-hidden--bp35">8</td>
# <td class="standing-table__cell is-hidden--bp35">17</td>
# <td class="standing-table__cell is-hidden--bp35">45</td>
# <td class="standing-table__cell is-hidden--bp35">52</td>
# <td class="standing-table__cell">-7</td>
# <td class="standing-table__cell" data-sort-value="10">47</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="375">
# <td class="standing-table__cell">11</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Swansea City" data-short-name="Swansea City">
# <a class="standing-table__cell--name-link" href="/swansea-city">Swansea City</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">12</td>
# <td class="standing-table__cell is-hidden--bp35">11</td>
# <td class="standing-table__cell is-hidden--bp35">15</td>
# <td class="standing-table__cell is-hidden--bp35">44</td>
# <td class="standing-table__cell is-hidden--bp35">51</td>
# <td class="standing-table__cell">-7</td>
# <td class="standing-table__cell" data-sort-value="11">47</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="290">
# <td class="standing-table__cell">12</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Norwich City" data-short-name="Norwich City">
# <a class="standing-table__cell--name-link" href="/norwich-city">Norwich City</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">12</td>
# <td class="standing-table__cell is-hidden--bp35">11</td>
# <td class="standing-table__cell is-hidden--bp35">15</td>
# <td class="standing-table__cell is-hidden--bp35">52</td>
# <td class="standing-table__cell is-hidden--bp35">66</td>
# <td class="standing-table__cell">-14</td>
# <td class="standing-table__cell" data-sort-value="12">47</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="415">
# <td class="standing-table__cell">13</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Sunderland" data-short-name="Sunderland">
# <a class="standing-table__cell--name-link" href="/sunderland">Sunderland</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">11</td>
# <td class="standing-table__cell is-hidden--bp35">12</td>
# <td class="standing-table__cell is-hidden--bp35">15</td>
# <td class="standing-table__cell is-hidden--bp35">45</td>
# <td class="standing-table__cell is-hidden--bp35">46</td>
# <td class="standing-table__cell">-1</td>
# <td class="standing-table__cell" data-sort-value="13">45</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="384">
# <td class="standing-table__cell">14</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Stoke City" data-short-name="Stoke City">
# <a class="standing-table__cell--name-link" href="/stoke-city">Stoke City</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">11</td>
# <td class="standing-table__cell is-hidden--bp35">12</td>
# <td class="standing-table__cell is-hidden--bp35">15</td>
# <td class="standing-table__cell is-hidden--bp35">36</td>
# <td class="standing-table__cell is-hidden--bp35">53</td>
# <td class="standing-table__cell">-17</td>
# <td class="standing-table__cell" data-sort-value="14">45</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="457">
# <td class="standing-table__cell">15</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Wigan Athletic" data-short-name="Wigan Athletic">
# <a class="standing-table__cell--name-link" href="/wigan-athletic">Wigan Athletic</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">11</td>
# <td class="standing-table__cell is-hidden--bp35">10</td>
# <td class="standing-table__cell is-hidden--bp35">17</td>
# <td class="standing-table__cell is-hidden--bp35">42</td>
# <td class="standing-table__cell is-hidden--bp35">62</td>
# <td class="standing-table__cell">-20</td>
# <td class="standing-table__cell" data-sort-value="15">43</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="238">
# <td class="standing-table__cell">16</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Aston Villa" data-short-name="Aston Villa">
# <a class="standing-table__cell--name-link" href="/aston-villa">Aston Villa</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">7</td>
# <td class="standing-table__cell is-hidden--bp35">17</td>
# <td class="standing-table__cell is-hidden--bp35">14</td>
# <td class="standing-table__cell is-hidden--bp35">37</td>
# <td class="standing-table__cell is-hidden--bp35">53</td>
# <td class="standing-table__cell">-16</td>
# <td class="standing-table__cell" data-sort-value="16">38</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="411">
# <td class="standing-table__cell">17</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Queens Park Rangers" data-short-name="Queens Park Rangers">
# <a class="standing-table__cell--name-link" href="/queens-park-rangers">Queens Park Rangers</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">10</td>
# <td class="standing-table__cell is-hidden--bp35">7</td>
# <td class="standing-table__cell is-hidden--bp35">21</td>
# <td class="standing-table__cell is-hidden--bp35">43</td>
# <td class="standing-table__cell is-hidden--bp35">66</td>
# <td class="standing-table__cell">-23</td>
# <td class="standing-table__cell" data-sort-value="17">37</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row standing-table__row--divider" data-item-id="555">
# <td class="standing-table__cell">18</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Bolton Wanderers" data-short-name="Bolton Wanderers">
# <a class="standing-table__cell--name-link" href="/bolton-wanderers">Bolton Wanderers</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">10</td>
# <td class="standing-table__cell is-hidden--bp35">6</td>
# <td class="standing-table__cell is-hidden--bp35">22</td>
# <td class="standing-table__cell is-hidden--bp35">46</td>
# <td class="standing-table__cell is-hidden--bp35">77</td>
# <td class="standing-table__cell">-31</td>
# <td class="standing-table__cell" data-sort-value="18">36</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="262">
# <td class="standing-table__cell">19</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Blackburn Rovers" data-short-name="Blackburn Rovers">
# <a class="standing-table__cell--name-link" href="/blackburn-rovers">Blackburn Rovers</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">8</td>
# <td class="standing-table__cell is-hidden--bp35">7</td>
# <td class="standing-table__cell is-hidden--bp35">23</td>
# <td class="standing-table__cell is-hidden--bp35">48</td>
# <td class="standing-table__cell is-hidden--bp35">78</td>
# <td class="standing-table__cell">-30</td>
# <td class="standing-table__cell" data-sort-value="19">31</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# <tr class="standing-table__row" data-item-id="206">
# <td class="standing-table__cell">20</td>
# <td class="standing-table__cell standing-table__cell--name" data-long-name="Wolverhampton Wanderers" data-short-name="Wolverhampton Wanderers">
# <a class="standing-table__cell--name-link" href="/wolverhampton-wanderers">Wolverhampton Wanderers</a>
# </td>
# <td class="standing-table__cell">38</td>
# <td class="standing-table__cell is-hidden--bp35">5</td>
# <td class="standing-table__cell is-hidden--bp35">10</td>
# <td class="standing-table__cell is-hidden--bp35">23</td>
# <td class="standing-table__cell is-hidden--bp35">40</td>
# <td class="standing-table__cell is-hidden--bp35">82</td>
# <td class="standing-table__cell">-42</td>
# <td class="standing-table__cell" data-sort-value="20">25</td>
# <td class="standing-table__cell is-hidden--bp15 is-hidden--bp35 is-hidden" data-sort-value="0">
# </td>
# </tr>
# </tbody>]

# %%
for league_teams in league_table:
    rows = league_teams.find_all('tr')
    #print(rows)
    for row in rows:
        team_names = row.find('td',class_ = 'standing-table__cell standing-table__cell--name').text.strip()
        team_points = row.find_all('td', class_ ='standing-table__cell')[9].text.strip()
        print(team_names,team_points)
# Out:
# Manchester City 89
# Manchester United 89
# Arsenal 70
# Tottenham Hotspur 69
# Newcastle United 65
# Chelsea 64
# Everton 56
# Liverpool 52
# Fulham 52
# West Bromwich Albion 47
# Swansea City 47
# Norwich City 47
# Sunderland 45
# Stoke City 45
# Wigan Athletic 43
# Aston Villa 38
# Queens Park Rangers 37
# Bolton Wanderers 36
# Blackburn Rovers 31
# Wolverhampton Wanderers 25

# %%
import pandas as pd

# %%
league_2011 = []
for league_teams in league_table:
    rows = league_teams.find_all('tr')
    #print(rows)
    for row in rows:
        team_names = row.find('td',class_ = 'standing-table__cell standing-table__cell--name').text.strip()
        team_points = row.find_all('td', class_ ='standing-table__cell')[9].text.strip()
        GD = row.find_all('td', class_ ='standing-table__cell')[8].text.strip()
        league_dict = {'name': team_names,
                      'pts': team_points,
                       'gd' : GD
                      }
        league_2011.append(league_dict)

# %%
df = pd.DataFrame(league_2011)

# %%
df
# Out:
#                        name pts   gd
# 0           Manchester City  89   64
# 1         Manchester United  89   56
# 2                   Arsenal  70   25
# 3         Tottenham Hotspur  69   25
# 4          Newcastle United  65    5
# 5                   Chelsea  64   19
# 6                   Everton  56   10
# 7                 Liverpool  52    7
# 8                    Fulham  52   -3
# 9      West Bromwich Albion  47   -7
# 10             Swansea City  47   -7
# 11             Norwich City  47  -14
# 12               Sunderland  45   -1
# 13               Stoke City  45  -17
# 14           Wigan Athletic  43  -20
# 15              Aston Villa  38  -16
# 16      Queens Park Rangers  37  -23
# 17         Bolton Wanderers  36  -31
# 18         Blackburn Rovers  31  -30
# 19  Wolverhampton Wanderers  25  -42
